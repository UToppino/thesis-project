# %% [markdown]
# ## MLP-only classification
# Extract heartbeats from raw dataset and trains an MLP for classification:
# - Extract all usable heartbeats of fixed length from the raw data
# - Trains a MLP network with fixed parameters

# %%
# Importing packages
import copy
import datetime
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math
from scipy import signal
import keras
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
import keras
import keras_tuner as kt
from keras.utils import to_categorical
from keras.layers import Dense, Convolution1D, Convolution2D, MaxPool1D, Flatten, Dropout, AveragePooling1D
from keras.layers import Input
from keras import initializers
from keras.models import Model, Sequential
from keras.layers import BatchNormalization
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.utils import class_weight
from sklearn.utils import resample
import warnings
import wfdb
import os
import tensorflow as tf
warnings.filterwarnings('ignore')

# %%
### PARAMETERS TO SET ###

# Balance the weight of the different classes of the (unbalanced) dataset
CUSTOM_WEIGHTS = True

# Parameters for heartbeat extraction
# Number of samples to consider as the length of an heartbeat
HEARTBEAT_LENGTH = 300
# Number of random points to extract from heartbeat
POINTS_LENGTH = 35

# Parameters for float to integer conversion
# 16bits max and min values
INT_RANGE = 65536
INT_LOW = -32768
INT_HIGH = 32767
# Wether to convert down to 8bit or stay at 16bit
CONV_8BIT = True
print("Range: "+str(INT_RANGE)+"   MIN: "+str(INT_LOW)+"   MAX:"+str(INT_HIGH))

# Parameters for saving files
# Confusion matrix img is saved in LOG_DIR
# Model is stored in MODEL_PATH_BASE with name MODEL_NAME_BASE plus two digits
LOG_DIR = "logs/mlp_only/"
MODEL_NAME_BASE = 'mlp_only_'
MODEL_PATH_BASE = 'models/mlp_only/'
# Out:
# Range: 65536   MIN: -32768   MAX:32767

# %%
# Parameters for determinism
KERAS_SEED = 1234509876
keras.utils.set_random_seed(KERAS_SEED)
tf.config.experimental.enable_op_determinism()

# %%
### Extract data from files
mitdb_list = [100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 111, 112, 113, 114, 115, 116, 117, 118, 119, 121, 122, 123, 124, 200, 201, 202, 203, 205, 207, 208, 209, 210, 212, 213, 214, 215, 217, 219, 220, 221, 222, 223, 228, 230, 231, 232, 233, 234]

if CONV_8BIT:
    v_dataset_data = np.empty((1,HEARTBEAT_LENGTH), dtype=np.int8)
else:
    v_dataset_data = np.empty((1,HEARTBEAT_LENGTH), dtype=np.int16)

# Float dataset
v_dataset_data = np.empty((1,HEARTBEAT_LENGTH), dtype=float)
v_dataset_categ = np.empty(1, dtype=str)

v_data_min = 10.0
v_data_max = -10.0

for element in mitdb_list:
    record = wfdb.rdrecord('src/mitdb/' + str(element))
    v_data_min = np.min(record.p_signal) if np.min(record.p_signal) < v_data_min else v_data_min
    v_data_max = np.max(record.p_signal) if np.max(record.p_signal) > v_data_max else v_data_max

v_data_abs_max = np.max(np.abs([v_data_min, v_data_max]))

print("MAX: " + str(v_data_max) + "   MIN: " + str(v_data_min))
print("ABS MAX: " +str(v_data_abs_max))

for element in mitdb_list:


    print("##########")
    print("Current record: " + str(element))

    # Load all samples
    record = wfdb.rdrecord('src/mitdb/' + str(element))
    annotation = wfdb.rdann('src/mitdb/'+str(element), 'atr')

    # Convert annotations to useful ones
    # Read symbols and substitute them
    # Classes:  'N': Normal beat
    #           'S': Supraventricular premature
    #           'V': Premature ventricular contraction
    #           'F': Fusion of ventricular and normal beat
    #           'Q': Unclassifiable
    #
    # CLASSIFICATION
    # Based on the paper "A deep convolutional neural network model to classify heartbeats"
    symbol_dict = { 'N':'N', 'L':'N', 'R':'N', 'e':'N', 'j':'N',
                    'S':'S', 'A':'S', 'a':'S', 'J':'S',
                    'V':'V', 'E':'V',
                    'F':'F',
                    'Q':'Q', '/':'Q', 'f':'Q'}
    raw_ann_symbol = annotation.symbol.copy()
    raw_ann_sample = annotation.sample.copy()
    #raw_ann_symbol = [symbol_dict[key] if key in symbol_dict else key for key in raw_ann_symbol]
    raw_ann_symbol = [symbol_dict[key] if key in symbol_dict else 'Z' for key in raw_ann_symbol]

    # Delete non beat annotations
    if 'Z' in raw_ann_symbol:
        i_del = [i for i, x in enumerate(raw_ann_symbol) if x == 'Z']
        raw_ann_sample = np.delete(raw_ann_sample, i_del)
        raw_ann_symbol = np.delete(raw_ann_symbol, i_del)

    # Extract ECG data array
    v_data_f = record.p_signal
    v_data_f = v_data_f[:,0]

    # Convert data from float to uint16
    #v_data = np.zeros_like(v_data_f, dtype=np.int16)
    #for i in range(0, len(v_data_f)):
    #    # Offset and scale
    #    #v_data[i] = ((v_data_f[i]-v_data_min)/(v_data_max - v_data_min))*(INT_RANGE)+(INT_LOW)
    #    # Scale only
    #    v_data[i] = np.int16((v_data_f[i])/(v_data_abs_max)*(INT_HIGH))
    #    if CONV_8BIT:
    #        v_data[i] = np.int8((v_data[i] >> 8) & 0xFF)

    # If using float instead of int
    #v_data = v_data_f/v_data_abs_max*INT_HIGH
    v_data = v_data_f

    print(v_data_f)
    print(v_data)

    # Define time array (Fs:360Hz)
    v_time = np.arange(0, HEARTBEAT_LENGTH, 1, dtype=int)

    # Zeros array for x-axis
    axis_x = np.zeros_like(v_time)

    # Delete annotations for beats too close to the beginning or ending of signal
    raw_ann_symbol = raw_ann_symbol[(raw_ann_sample > (HEARTBEAT_LENGTH/2+1)) & (raw_ann_sample < (len(v_data)-(HEARTBEAT_LENGTH/2+1)))]
    raw_ann_sample = raw_ann_sample[(raw_ann_sample > (HEARTBEAT_LENGTH/2+1)) & (raw_ann_sample < (len(v_data)-(HEARTBEAT_LENGTH/2+1)))]

    print(raw_ann_symbol)
    print(raw_ann_sample)
    print(len(raw_ann_symbol))
    print(len(raw_ann_sample))
    
    # Divide signal in single heartbeats
    v_total_data = np.zeros(shape=(len(raw_ann_symbol),HEARTBEAT_LENGTH))
    v_total_categ = np.empty(len(raw_ann_symbol), dtype=str)
    for i in range(0, len(v_total_data)-1):
        v_total_data[i,:] = v_data[(raw_ann_sample[i] - int(HEARTBEAT_LENGTH/2)) : (raw_ann_sample[i] + int(HEARTBEAT_LENGTH/2))]
        v_total_categ[i] = raw_ann_symbol[i]
        #print(v_total_data[i,:])

    # Delete empty data
    v_total_data = v_total_data[v_total_categ != '']
    v_total_categ = v_total_categ[v_total_categ != '']

    # Copy results to dataset variables
    v_dataset_data = np.append(v_dataset_data, v_total_data, axis=0)
    v_dataset_categ = np.append(v_dataset_categ, v_total_categ)

# Delete first element (empty)
v_dataset_data = v_dataset_data[1:,:]
v_dataset_categ = v_dataset_categ[1:]

print(v_dataset_categ)
print(v_dataset_data)
# Out:
# MAX: 5.115   MIN: -5.12
# ABS MAX: 5.12
# ##########
# Current record: 100
# [-0.145 -0.145 -0.145 ... -0.675 -0.765 -1.28 ]
# [-0.145 -0.145 -0.145 ... -0.675 -0.765 -1.28 ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   370    662    946 ... 649232 649484 649734]
# 2271
# 2271
# ##########
# Current record: 101
# [-0.345 -0.345 -0.345 ... -0.295 -0.29   0.   ]
# [-0.345 -0.345 -0.345 ... -0.295 -0.29   0.   ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   396    711   1032 ... 649004 649372 649751]
# 1864
# 1864
# ##########
# Current record: 102
# [-0.2   -0.2   -0.2   ... -0.17  -0.195  0.   ]
# [-0.2   -0.2   -0.2   ... -0.17  -0.195  0.   ]
# ['Q' 'Q' 'Q' ... 'Q' 'Q' 'Q']
# [   410    697    989 ... 648931 649244 649553]
# 2185
# 2185
# ##########
# Current record: 103
# [-0.375 -0.375 -0.375 ... -0.235 -0.245  0.   ]
# [-0.375 -0.375 -0.375 ... -0.235 -0.245  0.   ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   265    575    876 ... 648872 649195 649534]
# 2083
# 2083
# ##########
# Current record: 104
# [-0.15  -0.15  -0.15  ... -0.065 -0.06   0.   ]
# [-0.15  -0.15  -0.15  ... -0.065 -0.06   0.   ]
# ['Q' 'Q' 'Q' ... 'Q' 'Q' 'Q']
# [   316    615    901 ... 649022 649300 649580]
# 2227
# 2227
# ##########
# Current record: 105
# [-0.445 -0.445 -0.445 ...  0.59   0.76   1.28 ]
# [-0.445 -0.445 -0.445 ...  0.59   0.76   1.28 ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   197    459    708 ... 649221 649471 649740]
# 2572
# 2572
# ##########
# Current record: 106
# [-0.31  -0.31  -0.31  ...  0.635  0.265  0.   ]
# [-0.31  -0.31  -0.31  ...  0.635  0.265  0.   ]
# ['N' 'N' 'N' ... 'V' 'V' 'N']
# [   351    724   1086 ... 649162 649340 649791]
# 2027
# 2027
# ##########
# Current record: 107
# [-2.045 -2.045 -2.045 ... -0.645 -0.635  0.   ]
# [-2.045 -2.045 -2.045 ... -0.645 -0.635  0.   ]
# ['Q' 'Q' 'Q' ... 'Q' 'Q' 'Q']
# [   272    569    884 ... 649129 649441 649748]
# 2136
# 2136
# ##########
# Current record: 108
# [-0.125 -0.125 -0.125 ... -0.01   0.04   0.   ]
# [-0.125 -0.125 -0.125 ... -0.01   0.04   0.   ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   442    789   1155 ... 649170 649471 649769]
# 1762
# 1762
# ##########
# Current record: 109
# [ 0.175  0.175  0.175 ... -0.92  -0.91  -1.28 ]
# [ 0.175  0.175  0.175 ... -0.92  -0.91  -1.28 ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   343    571    807 ... 649109 649378 649663]
# 2530
# 2530
# ##########
# Current record: 111
# [-0.035 -0.035 -0.035 ...  0.155  0.2    0.   ]
# [-0.035 -0.035 -0.035 ...  0.155  0.2    0.   ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   197    489    804 ... 649148 649441 649724]
# 2124
# 2124
# ##########
# Current record: 112
# [-0.75  -0.75  -0.75  ... -0.825 -0.81  -1.28 ]
# [-0.75  -0.75  -0.75  ... -0.825 -0.81  -1.28 ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   382    644    892 ... 649105 649361 649626]
# 2537
# 2537
# ##########
# Current record: 113
# [-0.46 -0.46 -0.46 ...  1.06  0.42  0.  ]
# [-0.46 -0.46 -0.46 ...  1.06  0.42  0.  ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   170    583    966 ... 649008 649364 649675]
# 1794
# 1794
# ##########
# Current record: 114
# [-0.045 -0.045 -0.045 ... -0.365 -0.37   0.   ]
# [-0.045 -0.045 -0.045 ... -0.365 -0.37   0.   ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   310    726   1143 ... 649261 649523 649783]
# 1879
# 1879
# ##########
# Current record: 115
# [-0.58 -0.58 -0.58 ... -0.75 -0.75 -1.28]
# [-0.58 -0.58 -0.58 ... -0.75 -0.75 -1.28]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   161    518    850 ... 649055 649357 649647]
# 1952
# 1952
# ##########
# Current record: 116
# [-0.32  -0.32  -0.32  ... -0.975 -0.96  -1.28 ]
# [-0.32  -0.32  -0.32  ... -0.975 -0.96  -1.28 ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   282    561    837 ... 649191 649442 649701]
# 2411
# 2411
# ##########
# Current record: 117
# [-0.925 -0.925 -0.925 ... -0.585 -0.565  0.   ]
# [-0.925 -0.925 -0.925 ... -0.585 -0.565  0.   ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   189    598   1006 ... 648653 649070 649498]
# 1534
# 1534
# ##########
# Current record: 118
# [-0.835 -0.835 -0.835 ...  0.03   0.085  0.   ]
# [-0.835 -0.835 -0.835 ...  0.03   0.085  0.   ]
# ['N' 'N' 'N' ... 'N' 'S' 'N']
# [   369    674    980 ... 649226 649429 649742]
# 2277
# 2277
# ##########
# Current record: 119
# [-0.995 -0.995 -0.995 ...  1.565  1.525  1.28 ]
# [-0.995 -0.995 -0.995 ...  1.565  1.525  1.28 ]
# ['N' 'V' 'N' ... 'N' 'N' 'N']
# [   309    503    977 ... 649129 649468 649788]
# 1987
# 1987
# ##########
# Current record: 121
# [-0.875 -0.875 -0.875 ... -0.86  -0.875 -1.28 ]
# [-0.875 -0.875 -0.875 ... -0.86  -0.875 -1.28 ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   163    513    874 ... 648996 649287 649587]
# 1862
# 1862
# ##########
# Current record: 122
# [-0.78 -0.78 -0.78 ... -1.02 -1.04 -1.28]
# [-0.78 -0.78 -0.78 ... -1.02 -1.04 -1.28]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   326    561    798 ... 649126 649383 649643]
# 2474
# 2474
# ##########
# Current record: 123
# [-0.805 -0.805 -0.805 ... -1.25  -1.225 -1.28 ]
# [-0.805 -0.805 -0.805 ... -1.25  -1.225 -1.28 ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   550   1021   1498 ... 648997 649342 649689]
# 1517
# 1517
# ##########
# Current record: 124
# [-1.    -1.    -1.    ... -0.72  -0.705 -1.28 ]
# [-1.    -1.    -1.    ... -0.72  -0.705 -1.28 ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   243    693   1119 ... 648786 649146 649510]
# 1618
# 1618
# ##########
# Current record: 200
# [0.35  0.35  0.35  ... 0.015 0.015 0.   ]
# [0.35  0.35  0.35  ... 0.015 0.015 0.   ]
# ['V' 'N' 'V' ... 'N' 'N' 'N']
# [   225    487    689 ... 649161 649408 649664]
# 2600
# 2600
# ##########
# Current record: 201
# [-0.26 -0.26 -0.26 ... -0.17 -0.18  0.  ]
# [-0.26 -0.26 -0.26 ... -0.17 -0.18  0.  ]
# ['N' 'N' 'N' ... 'S' 'N' 'N']
# [   159    415    686 ... 648594 649104 649800]
# 1963
# 1963
# ##########
# Current record: 202
# [ 0.    0.    0.   ... -0.24 -0.24  0.  ]
# [ 0.    0.    0.   ... -0.24 -0.24  0.  ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   348    742   1155 ... 649092 649342 649615]
# 2135
# 2135
# ##########
# Current record: 203
# [-0.26 -0.26 -0.26 ... -0.55 -0.52  0.  ]
# [-0.26 -0.26 -0.26 ... -0.55 -0.52  0.  ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   431    660    862 ... 649237 649448 649777]
# 2979
# 2979
# ##########
# Current record: 205
# [-0.43  -0.43  -0.43  ... -0.365 -0.375  0.   ]
# [-0.43  -0.43  -0.43  ... -0.365 -0.375  0.   ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   229    466    706 ... 649060 649326 649596]
# 2655
# 2655
# ##########
# Current record: 207
# [-0.215 -0.215 -0.215 ... -1.19  -1.135 -1.28 ]
# [-0.215 -0.215 -0.215 ... -1.19  -1.135 -1.28 ]
# ['V' 'N' 'V' ... 'S' 'S' 'S']
# [   312    835   1078 ... 649431 649602 649799]
# 1859
# 1859
# ##########
# Current record: 208
# [-0.105 -0.105 -0.105 ... -0.17  -0.16   0.   ]
# [-0.105 -0.105 -0.105 ... -0.17  -0.16   0.   ]
# ['V' 'N' 'F' ... 'N' 'V' 'N']
# [   209    483    697 ... 649206 649411 649704]
# 2953
# 2953
# ##########
# Current record: 209
# [-0.02  -0.02  -0.02  ... -0.265 -0.28   0.   ]
# [-0.02  -0.02  -0.02  ... -0.265 -0.28   0.   ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   189    425    659 ... 649149 649387 649627]
# 3004
# 3004
# ##########
# Current record: 210
# [-0.065 -0.065 -0.065 ... -0.305 -0.3    0.   ]
# [-0.065 -0.065 -0.065 ... -0.305 -0.3    0.   ]
# ['N' 'N' 'V' ... 'N' 'V' 'N']
# [   250    471    625 ... 649216 649513 649758]
# 2648
# 2648
# ##########
# Current record: 212
# [-0.5  -0.5  -0.5  ... -0.34 -0.33  0.  ]
# [-0.5  -0.5  -0.5  ... -0.34 -0.33  0.  ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   214    451    696 ... 649141 649414 649673]
# 2747
# 2747
# ##########
# Current record: 213
# [-0.01  -0.01  -0.01  ...  1.135  0.715  1.28 ]
# [-0.01  -0.01  -0.01  ...  1.135  0.715  1.28 ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   253    478    673 ... 649374 649577 649790]
# 3249
# 3249
# ##########
# Current record: 214
# [-0.095 -0.095 -0.095 ... -0.32  -0.285  0.   ]
# [-0.095 -0.095 -0.095 ... -0.32  -0.285  0.   ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   346    660    975 ... 649112 649379 649627]
# 2260
# 2260
# ##########
# Current record: 215
# [ 0.22   0.22   0.22  ... -0.285 -0.28   0.   ]
# [ 0.22   0.22   0.22  ... -0.285 -0.28   0.   ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   313    503    704 ... 649304 649501 649685]
# 3361
# 3361
# ##########
# Current record: 217
# [ 0.045  0.045  0.045 ... -0.36  -0.33   0.   ]
# [ 0.045  0.045  0.045 ... -0.36  -0.33   0.   ]
# ['Q' 'Q' 'Q' ... 'Q' 'Q' 'Q']
# [   205    500    812 ... 649114 649429 649738]
# 2208
# 2208
# ##########
# Current record: 219
# [-0.695 -0.695 -0.695 ... -0.89  -0.885 -1.28 ]
# [-0.695 -0.695 -0.695 ... -0.89  -0.885 -1.28 ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   300    614    887 ... 649174 649448 649737]
# 2154
# 2154
# ##########
# Current record: 220
# [-0.69  -0.69  -0.69  ... -0.16  -0.155  0.   ]
# [-0.69  -0.69  -0.69  ... -0.16  -0.155  0.   ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   313    612    916 ... 648966 649277 649584]
# 2046
# 2046
# ##########
# Current record: 221
# [-0.285 -0.285 -0.285 ... -0.235 -0.245  0.   ]
# [-0.285 -0.285 -0.285 ... -0.235 -0.245  0.   ]
# ['N' 'N' 'V' ... 'N' 'N' 'N']
# [   220    442    603 ... 649236 649530 649810]
# 2427
# 2427
# ##########
# Current record: 222
# [-0.14 -0.14 -0.14 ... -0.27 -0.28  0.  ]
# [-0.14 -0.14 -0.14 ... -0.27 -0.28  0.  ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   361    646    892 ... 649157 649317 649600]
# 2481
# 2481
# ##########
# Current record: 223
# [-0.93  -0.93  -0.93  ... -0.55  -0.555  0.   ]
# [-0.93  -0.93  -0.93  ... -0.55  -0.555  0.   ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   204    480    759 ... 649091 649349 649599]
# 2604
# 2604
# ##########
# Current record: 228
# [-0.155 -0.155 -0.155 ... -0.29  -0.285  0.   ]
# [-0.155 -0.155 -0.155 ... -0.29  -0.285  0.   ]
# ['N' 'N' 'N' ... 'N' 'V' 'N']
# [   160    433    726 ... 649108 649332 649761]
# 2053
# 2053
# ##########
# Current record: 230
# [-0.38 -0.38 -0.38 ... -0.59 -0.59  0.  ]
# [-0.38 -0.38 -0.38 ... -0.59 -0.59  0.  ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   349    616    880 ... 649338 649572 649807]
# 2255
# 2255
# ##########
# Current record: 231
# [-0.2  -0.2  -0.2  ...  0.34  0.34  0.  ]
# [-0.2  -0.2  -0.2  ...  0.34  0.34  0.  ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   180    527    847 ... 648811 649142 649501]
# 1570
# 1570
# ##########
# Current record: 232
# [-0.245 -0.245 -0.245 ... -0.07  -0.075  0.   ]
# [-0.245 -0.245 -0.245 ... -0.07  -0.075  0.   ]
# ['N' 'S' 'S' ... 'N' 'S' 'S']
# [   491    737   1000 ... 648845 649097 649366]
# 1780
# 1780
# ##########
# Current record: 233
# [-0.095 -0.095 -0.095 ... -0.495 -0.49   0.   ]
# [-0.095 -0.095 -0.095 ... -0.495 -0.49   0.   ]
# ['N' 'V' 'N' ... 'V' 'N' 'N']
# [   320    511    749 ... 649237 649518 649730]
# 3077
# 3077
# ##########
# Current record: 234
# [-0.08  -0.08  -0.08  ... -0.395 -0.38   0.   ]
# [-0.08  -0.08  -0.08  ... -0.395 -0.38   0.   ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   366    606    841 ... 649292 649536 649772]
# 2752
# 2752
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [[-0.26  -0.265 -0.27  ... -0.295 -0.29  -0.305]
#  [-0.315 -0.305 -0.315 ... -0.35  -0.34  -0.335]
#  [-0.32  -0.325 -0.305 ... -0.3   -0.31  -0.33 ]
#  ...
#  [-0.215 -0.215 -0.225 ... -0.25  -0.265 -0.28 ]
#  [-0.25  -0.23  -0.22  ... -0.225 -0.24  -0.24 ]
#  [-0.25  -0.245 -0.225 ... -0.19  -0.185 -0.18 ]]

# %%
# Extract N random numbers from heartbeat
random_indices = np.random.choice(HEARTBEAT_LENGTH, size=POINTS_LENGTH, replace=False)
random_indices = np.sort(random_indices)
v_dataset_data_rand = [arr[random_indices] for arr in v_dataset_data]
print(v_dataset_data)
print(random_indices)
# Out:
# [[-0.26  -0.265 -0.27  ... -0.295 -0.29  -0.305]
#  [-0.315 -0.305 -0.315 ... -0.35  -0.34  -0.335]
#  [-0.32  -0.325 -0.305 ... -0.3   -0.31  -0.33 ]
#  ...
#  [-0.215 -0.215 -0.225 ... -0.25  -0.265 -0.28 ]
#  [-0.25  -0.23  -0.22  ... -0.225 -0.24  -0.24 ]
#  [-0.25  -0.245 -0.225 ... -0.19  -0.185 -0.18 ]]
# [  0  17  28  29  37  40  43  44  46  50  56  71  72  77  78  84 101 134
#  146 150 157 169 181 189 194 196 200 207 224 231 235 238 243 259 265]

# %%
# Backup dataset to other variable
#v_dataset_data_bk = np.copy(v_dataset_data)
v_dataset_data_bk = np.copy(v_dataset_data_rand)
v_dataset_categ_bk = np.copy(v_dataset_categ)

# %%
# Plotting window
X_MIN = 0
X_MAX = 400
N_ROW = 3
N_COL = 1
PLOT_LOW = INT_LOW
PLOT_HIGH = INT_HIGH

if CONV_8BIT:
    PLOT_LOW = -128
    PLOT_HIGH = 127

n = 0
# Create plots
fig, axs = plt.subplots(N_ROW, N_COL, sharex=True)
fig.set_size_inches(15, 4*N_ROW)
fig.suptitle("ECG Signal conditioning")
axs[n].set_xlim(X_MIN, X_MAX)

# First plot
axs[n].title.set_text('Plot')
axs[n].plot(v_data, 'b', label="raw data", linewidth=0.5)
#axs[n].set_ylim([PLOT_LOW, PLOT_HIGH])
n += 1

# First plot
axs[n].title.set_text('Plot')
axs[n].plot(v_data_f, 'b', label="raw data", linewidth=0.5)
#axs[n].set_ylim([v_data_min, v_data_max])
n += 1

# First plot
axs[n].title.set_text('Plot')
axs[n].plot(v_dataset_data[1], 'b', label="raw data", linewidth=0.5)
axs[n].plot(random_indices, v_dataset_data[1][random_indices], 'ro', label="raw data", linewidth=0.5)
n += 1


# First plot
#axs[n].title.set_text('Plot')
#axs[n].plot(v_time, axis_x, linewidth=0.2, color="black")
#axs[n].plot(v_time, v_dataset_data[n], 'b', label="raw data", linewidth=0.5)
#axs[n].legend()
#n += 1

# First plot
#axs[n].title.set_text('Plot')
#axs[n].plot(v_time, axis_x, linewidth=0.2, color="black")
#axs[n].plot(v_time, v_data, 'b', label="raw data", linewidth=0.5)
#axs[n].plot(v_peaks_R_time, v_peaks_R_data, 'mo', label="R peaks", linewidth=0.5)
#axs[n].plot(v_peaks_P_time, v_peaks_P_data, 'bo', label="P peaks", linewidth=0.5)
#axs[n].plot(v_peaks_T_time, v_peaks_T_data, 'ro', label="T peaks", linewidth=0.5)
#axs[n].legend()
#n += 1

plt.tight_layout()
plt.show()

# %%
# Copy from backup data
dataset_categ = np.copy(v_dataset_categ_bk)
dataset_data = np.copy(v_dataset_data_bk)

# Convert symbols to numbers
category_dict = {   'N':0,
                    'S':1,
                    'V':2,
                    'F':3,
                    'Q':4}
dataset_categ = [category_dict[key] if key in category_dict else 'Z' for key in dataset_categ]

# Divide data into sets
DATA_SPLIT = 0.2
SEED = 1029384756
set_train, x_valid, target_train, y_valid = train_test_split(dataset_data, dataset_categ, test_size=DATA_SPLIT, random_state=SEED)
x_train, x_test, y_train, y_test = train_test_split(set_train, target_train, test_size=DATA_SPLIT, random_state=SEED)

y_train=to_categorical(y_train)
y_test=to_categorical(y_test)
y_valid=to_categorical(y_valid)

# %%
# Calculate cutom weights for training
tot_y_train = np.sum(y_train, axis=0)
tot_y_test = np.sum(y_test, axis=0)
tot_y_valid = np.sum(y_valid, axis=0)
tot_y_all = tot_y_train + tot_y_test + tot_y_valid

print(tot_y_train)
print(tot_y_test)
print(tot_y_valid)
print(tot_y_all)

max_class = np.max(tot_y_train)
#max_class = np.sum(tot_y_train)

custom_weights = {  0: int(max_class/tot_y_train[0]),
                    1: int(max_class/tot_y_train[1]),
                    2: int(max_class/tot_y_train[2]),
                    3: int(max_class/tot_y_train[3]),
                    4: int(max_class/tot_y_train[4])}

print(custom_weights)
# Out:
# [58060.  1779.  4552.   518.  5103.]
# [14455.   455.  1184.   127.  1283.]
# [18030.   545.  1499.   157.  1648.]
# [90545.  2779.  7235.   802.  8034.]
# {0: 1, 1: 32, 2: 12, 3: 112, 4: 11}

# %%
# Define NN structure
NEURONS = 20
LEARNING_RATE = 0.0001
model = Sequential([
    Input(shape=((x_train[0].shape[0],1)), name='inputs_nn'),
    Flatten(),    
    # Custom initial weights for deterministic behavior
    Dense(NEURONS, activation='relu', name="dense_1", kernel_initializer=initializers.GlorotUniform(seed=KERAS_SEED), bias_initializer='zeros'),
    Dense(5, activation='softmax', name='main_output', kernel_initializer=initializers.GlorotUniform(seed=KERAS_SEED), bias_initializer='zeros') 
])

model.compile(optimizer=keras.optimizers.Adam(learning_rate=LEARNING_RATE), loss='categorical_crossentropy',metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_5 (Flatten)             │ (None, 35)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 20)             │           720 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ main_output (Dense)             │ (None, 5)              │           105 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 825 (3.22 KB)
#  Trainable params: 825 (3.22 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Training parameters
EPOCH_NUM = 150
BATCH_SIZE = 64

# Train model
if (CUSTOM_WEIGHTS):
    history=model.fit(x_train, y_train, epochs=EPOCH_NUM, batch_size=BATCH_SIZE, validation_data=(x_valid,y_valid), class_weight=custom_weights)
else:
    history=model.fit(x_train, y_train, epochs=EPOCH_NUM, batch_size=BATCH_SIZE, validation_data=(x_valid,y_valid))
# Out:
# Epoch 1/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.4202 - loss: 6.5204 - val_accuracy: 0.4321 - val_loss: 1.4165
# Epoch 2/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.4559 - loss: 5.0805 - val_accuracy: 0.5222 - val_loss: 1.3058
# Epoch 3/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.5393 - loss: 4.4532 - val_accuracy: 0.6227 - val_loss: 1.1875
# Epoch 4/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6238 - loss: 4.0372 - val_accuracy: 0.6663 - val_loss: 1.0948
# Epoch 5/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6570 - loss: 3.7375 - val_accuracy: 0.6848 - val_loss: 1.0238
# Epoch 6/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.6733 - loss: 3.5050 - val_accuracy: 0.6865 - val_loss: 0.9716
# Epoch 7/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6653 - loss: 3.3221 - val_accuracy: 0.6783 - val_loss: 0.9411
# Epoch 8/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.6573 - loss: 3.1868 - val_accuracy: 0.6738 - val_loss: 0.9166
# Epoch 9/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.6559 - loss: 3.0785 - val_accuracy: 0.6745 - val_loss: 0.8956
# Epoch 10/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.6566 - loss: 2.9890 - val_accuracy: 0.6768 - val_loss: 0.8779
# Epoch 11/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6589 - loss: 2.9138 - val_accuracy: 0.6801 - val_loss: 0.8615
# Epoch 12/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6634 - loss: 2.8493 - val_accuracy: 0.6855 - val_loss: 0.8460
# Epoch 13/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6693 - loss: 2.7924 - val_accuracy: 0.6915 - val_loss: 0.8304
# Epoch 14/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.6768 - loss: 2.7399 - val_accuracy: 0.6969 - val_loss: 0.8179
# Epoch 15/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6825 - loss: 2.6908 - val_accuracy: 0.7001 - val_loss: 0.8091
# Epoch 16/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6864 - loss: 2.6483 - val_accuracy: 0.7036 - val_loss: 0.7996
# Epoch 17/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.6909 - loss: 2.6095 - val_accuracy: 0.7078 - val_loss: 0.7906
# Epoch 18/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6959 - loss: 2.5734 - val_accuracy: 0.7127 - val_loss: 0.7813
# Epoch 19/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6994 - loss: 2.5395 - val_accuracy: 0.7167 - val_loss: 0.7726
# Epoch 20/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7035 - loss: 2.5084 - val_accuracy: 0.7196 - val_loss: 0.7643
# Epoch 21/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7080 - loss: 2.4791 - val_accuracy: 0.7222 - val_loss: 0.7569
# Epoch 22/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7112 - loss: 2.4517 - val_accuracy: 0.7252 - val_loss: 0.7499
# Epoch 23/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7147 - loss: 2.4259 - val_accuracy: 0.7278 - val_loss: 0.7440
# Epoch 24/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7166 - loss: 2.4020 - val_accuracy: 0.7305 - val_loss: 0.7383
# Epoch 25/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7190 - loss: 2.3798 - val_accuracy: 0.7337 - val_loss: 0.7321
# Epoch 26/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7214 - loss: 2.3588 - val_accuracy: 0.7360 - val_loss: 0.7267
# Epoch 27/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7234 - loss: 2.3390 - val_accuracy: 0.7375 - val_loss: 0.7219
# Epoch 28/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7246 - loss: 2.3205 - val_accuracy: 0.7395 - val_loss: 0.7169
# Epoch 29/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7251 - loss: 2.3030 - val_accuracy: 0.7409 - val_loss: 0.7126
# Epoch 30/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7261 - loss: 2.2862 - val_accuracy: 0.7422 - val_loss: 0.7080
# Epoch 31/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7283 - loss: 2.2702 - val_accuracy: 0.7434 - val_loss: 0.7039
# Epoch 32/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7300 - loss: 2.2550 - val_accuracy: 0.7447 - val_loss: 0.7001
# Epoch 33/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7310 - loss: 2.2403 - val_accuracy: 0.7457 - val_loss: 0.6962
# Epoch 34/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7326 - loss: 2.2263 - val_accuracy: 0.7471 - val_loss: 0.6922
# Epoch 35/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7342 - loss: 2.2127 - val_accuracy: 0.7488 - val_loss: 0.6885
# Epoch 36/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7357 - loss: 2.1995 - val_accuracy: 0.7503 - val_loss: 0.6846
# Epoch 37/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7371 - loss: 2.1868 - val_accuracy: 0.7521 - val_loss: 0.6808
# Epoch 38/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7379 - loss: 2.1743 - val_accuracy: 0.7534 - val_loss: 0.6773
# Epoch 39/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7391 - loss: 2.1624 - val_accuracy: 0.7553 - val_loss: 0.6732
# Epoch 40/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7402 - loss: 2.1509 - val_accuracy: 0.7565 - val_loss: 0.6700
# Epoch 41/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7409 - loss: 2.1396 - val_accuracy: 0.7584 - val_loss: 0.6667
# Epoch 42/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7427 - loss: 2.1286 - val_accuracy: 0.7601 - val_loss: 0.6635
# Epoch 43/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7439 - loss: 2.1178 - val_accuracy: 0.7614 - val_loss: 0.6604
# Epoch 44/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7455 - loss: 2.1072 - val_accuracy: 0.7626 - val_loss: 0.6573
# Epoch 45/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7474 - loss: 2.0972 - val_accuracy: 0.7651 - val_loss: 0.6539
# Epoch 46/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7497 - loss: 2.0873 - val_accuracy: 0.7665 - val_loss: 0.6508
# Epoch 47/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7510 - loss: 2.0776 - val_accuracy: 0.7679 - val_loss: 0.6482
# Epoch 48/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7523 - loss: 2.0682 - val_accuracy: 0.7696 - val_loss: 0.6451
# Epoch 49/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7539 - loss: 2.0590 - val_accuracy: 0.7714 - val_loss: 0.6426
# Epoch 50/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7549 - loss: 2.0501 - val_accuracy: 0.7735 - val_loss: 0.6397
# Epoch 51/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7561 - loss: 2.0412 - val_accuracy: 0.7759 - val_loss: 0.6366
# Epoch 52/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7575 - loss: 2.0325 - val_accuracy: 0.7780 - val_loss: 0.6341
# Epoch 53/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7588 - loss: 2.0238 - val_accuracy: 0.7795 - val_loss: 0.6311
# Epoch 54/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7603 - loss: 2.0153 - val_accuracy: 0.7811 - val_loss: 0.6283
# Epoch 55/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7615 - loss: 2.0068 - val_accuracy: 0.7834 - val_loss: 0.6255
# Epoch 56/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7629 - loss: 1.9989 - val_accuracy: 0.7847 - val_loss: 0.6229
# Epoch 57/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7644 - loss: 1.9912 - val_accuracy: 0.7866 - val_loss: 0.6202
# Epoch 58/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7663 - loss: 1.9837 - val_accuracy: 0.7880 - val_loss: 0.6183
# Epoch 59/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7684 - loss: 1.9762 - val_accuracy: 0.7901 - val_loss: 0.6159
# Epoch 60/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7697 - loss: 1.9689 - val_accuracy: 0.7914 - val_loss: 0.6140
# Epoch 61/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7709 - loss: 1.9618 - val_accuracy: 0.7928 - val_loss: 0.6116
# Epoch 62/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7727 - loss: 1.9548 - val_accuracy: 0.7940 - val_loss: 0.6092
# Epoch 63/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7742 - loss: 1.9479 - val_accuracy: 0.7949 - val_loss: 0.6072
# Epoch 64/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7760 - loss: 1.9411 - val_accuracy: 0.7959 - val_loss: 0.6052
# Epoch 65/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7772 - loss: 1.9343 - val_accuracy: 0.7969 - val_loss: 0.6032
# Epoch 66/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7781 - loss: 1.9276 - val_accuracy: 0.7984 - val_loss: 0.6011
# Epoch 67/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7795 - loss: 1.9209 - val_accuracy: 0.7996 - val_loss: 0.5993
# Epoch 68/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7803 - loss: 1.9145 - val_accuracy: 0.8013 - val_loss: 0.5967
# Epoch 69/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7815 - loss: 1.9080 - val_accuracy: 0.8028 - val_loss: 0.5948
# Epoch 70/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7827 - loss: 1.9016 - val_accuracy: 0.8040 - val_loss: 0.5930
# Epoch 71/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7836 - loss: 1.8953 - val_accuracy: 0.8052 - val_loss: 0.5905
# Epoch 72/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7844 - loss: 1.8892 - val_accuracy: 0.8057 - val_loss: 0.5890
# Epoch 73/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7852 - loss: 1.8830 - val_accuracy: 0.8069 - val_loss: 0.5869
# Epoch 74/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7862 - loss: 1.8770 - val_accuracy: 0.8077 - val_loss: 0.5850
# Epoch 75/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7873 - loss: 1.8710 - val_accuracy: 0.8085 - val_loss: 0.5837
# Epoch 76/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7882 - loss: 1.8651 - val_accuracy: 0.8093 - val_loss: 0.5813
# Epoch 77/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7887 - loss: 1.8594 - val_accuracy: 0.8099 - val_loss: 0.5798
# Epoch 78/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7900 - loss: 1.8535 - val_accuracy: 0.8106 - val_loss: 0.5784
# Epoch 79/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7910 - loss: 1.8478 - val_accuracy: 0.8119 - val_loss: 0.5763
# Epoch 80/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7913 - loss: 1.8422 - val_accuracy: 0.8128 - val_loss: 0.5752
# Epoch 81/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7923 - loss: 1.8363 - val_accuracy: 0.8135 - val_loss: 0.5739
# Epoch 82/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7931 - loss: 1.8307 - val_accuracy: 0.8148 - val_loss: 0.5716
# Epoch 83/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7943 - loss: 1.8250 - val_accuracy: 0.8154 - val_loss: 0.5699
# Epoch 84/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7954 - loss: 1.8194 - val_accuracy: 0.8164 - val_loss: 0.5690
# Epoch 85/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7958 - loss: 1.8139 - val_accuracy: 0.8173 - val_loss: 0.5674
# Epoch 86/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7964 - loss: 1.8085 - val_accuracy: 0.8187 - val_loss: 0.5657
# Epoch 87/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7978 - loss: 1.8029 - val_accuracy: 0.8197 - val_loss: 0.5640
# Epoch 88/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7989 - loss: 1.7976 - val_accuracy: 0.8201 - val_loss: 0.5627
# Epoch 89/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7995 - loss: 1.7923 - val_accuracy: 0.8209 - val_loss: 0.5610
# Epoch 90/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8003 - loss: 1.7869 - val_accuracy: 0.8216 - val_loss: 0.5598
# Epoch 91/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8015 - loss: 1.7818 - val_accuracy: 0.8222 - val_loss: 0.5578
# Epoch 92/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8025 - loss: 1.7766 - val_accuracy: 0.8230 - val_loss: 0.5569
# Epoch 93/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8031 - loss: 1.7715 - val_accuracy: 0.8238 - val_loss: 0.5549
# Epoch 94/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8045 - loss: 1.7665 - val_accuracy: 0.8242 - val_loss: 0.5539
# Epoch 95/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8054 - loss: 1.7616 - val_accuracy: 0.8255 - val_loss: 0.5524
# Epoch 96/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8061 - loss: 1.7568 - val_accuracy: 0.8259 - val_loss: 0.5513
# Epoch 97/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8068 - loss: 1.7519 - val_accuracy: 0.8269 - val_loss: 0.5499
# Epoch 98/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8073 - loss: 1.7471 - val_accuracy: 0.8279 - val_loss: 0.5476
# Epoch 99/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8083 - loss: 1.7422 - val_accuracy: 0.8285 - val_loss: 0.5468
# Epoch 100/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8089 - loss: 1.7376 - val_accuracy: 0.8296 - val_loss: 0.5447
# Epoch 101/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8098 - loss: 1.7330 - val_accuracy: 0.8299 - val_loss: 0.5435
# Epoch 102/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8107 - loss: 1.7285 - val_accuracy: 0.8306 - val_loss: 0.5423
# Epoch 103/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8114 - loss: 1.7239 - val_accuracy: 0.8314 - val_loss: 0.5409
# Epoch 104/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8126 - loss: 1.7195 - val_accuracy: 0.8315 - val_loss: 0.5396
# Epoch 105/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8131 - loss: 1.7150 - val_accuracy: 0.8322 - val_loss: 0.5387
# Epoch 106/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8139 - loss: 1.7107 - val_accuracy: 0.8328 - val_loss: 0.5370
# Epoch 107/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8144 - loss: 1.7064 - val_accuracy: 0.8338 - val_loss: 0.5356
# Epoch 108/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8150 - loss: 1.7021 - val_accuracy: 0.8343 - val_loss: 0.5345
# Epoch 109/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8157 - loss: 1.6980 - val_accuracy: 0.8350 - val_loss: 0.5331
# Epoch 110/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8165 - loss: 1.6939 - val_accuracy: 0.8359 - val_loss: 0.5320
# Epoch 111/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8169 - loss: 1.6897 - val_accuracy: 0.8366 - val_loss: 0.5307
# Epoch 112/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8175 - loss: 1.6858 - val_accuracy: 0.8372 - val_loss: 0.5295
# Epoch 113/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8184 - loss: 1.6818 - val_accuracy: 0.8382 - val_loss: 0.5280
# Epoch 114/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8196 - loss: 1.6778 - val_accuracy: 0.8393 - val_loss: 0.5267
# Epoch 115/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8204 - loss: 1.6740 - val_accuracy: 0.8398 - val_loss: 0.5258
# Epoch 116/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8209 - loss: 1.6702 - val_accuracy: 0.8406 - val_loss: 0.5244
# Epoch 117/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8218 - loss: 1.6663 - val_accuracy: 0.8412 - val_loss: 0.5231
# Epoch 118/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8229 - loss: 1.6625 - val_accuracy: 0.8420 - val_loss: 0.5220
# Epoch 119/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8237 - loss: 1.6587 - val_accuracy: 0.8426 - val_loss: 0.5209
# Epoch 120/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8244 - loss: 1.6550 - val_accuracy: 0.8435 - val_loss: 0.5199
# Epoch 121/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8252 - loss: 1.6515 - val_accuracy: 0.8439 - val_loss: 0.5188
# Epoch 122/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8261 - loss: 1.6478 - val_accuracy: 0.8446 - val_loss: 0.5173
# Epoch 123/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8270 - loss: 1.6442 - val_accuracy: 0.8451 - val_loss: 0.5166
# Epoch 124/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8277 - loss: 1.6406 - val_accuracy: 0.8458 - val_loss: 0.5151
# Epoch 125/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8282 - loss: 1.6372 - val_accuracy: 0.8464 - val_loss: 0.5142
# Epoch 126/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8290 - loss: 1.6337 - val_accuracy: 0.8471 - val_loss: 0.5127
# Epoch 127/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8296 - loss: 1.6302 - val_accuracy: 0.8474 - val_loss: 0.5120
# Epoch 128/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8301 - loss: 1.6268 - val_accuracy: 0.8482 - val_loss: 0.5108
# Epoch 129/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8308 - loss: 1.6235 - val_accuracy: 0.8487 - val_loss: 0.5099
# Epoch 130/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8314 - loss: 1.6201 - val_accuracy: 0.8493 - val_loss: 0.5090
# Epoch 131/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8319 - loss: 1.6170 - val_accuracy: 0.8495 - val_loss: 0.5078
# Epoch 132/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8328 - loss: 1.6137 - val_accuracy: 0.8502 - val_loss: 0.5068
# Epoch 133/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8335 - loss: 1.6104 - val_accuracy: 0.8507 - val_loss: 0.5057
# Epoch 134/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8343 - loss: 1.6072 - val_accuracy: 0.8510 - val_loss: 0.5046
# Epoch 135/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8346 - loss: 1.6040 - val_accuracy: 0.8515 - val_loss: 0.5037
# Epoch 136/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8352 - loss: 1.6007 - val_accuracy: 0.8520 - val_loss: 0.5029
# Epoch 137/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8359 - loss: 1.5977 - val_accuracy: 0.8526 - val_loss: 0.5016
# Epoch 138/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8364 - loss: 1.5946 - val_accuracy: 0.8531 - val_loss: 0.5006
# Epoch 139/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8368 - loss: 1.5915 - val_accuracy: 0.8536 - val_loss: 0.4998
# Epoch 140/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8375 - loss: 1.5885 - val_accuracy: 0.8539 - val_loss: 0.4991
# Epoch 141/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8381 - loss: 1.5856 - val_accuracy: 0.8543 - val_loss: 0.4982
# Epoch 142/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8387 - loss: 1.5827 - val_accuracy: 0.8548 - val_loss: 0.4975
# Epoch 143/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8391 - loss: 1.5799 - val_accuracy: 0.8554 - val_loss: 0.4965
# Epoch 144/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8397 - loss: 1.5769 - val_accuracy: 0.8558 - val_loss: 0.4957
# Epoch 145/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8399 - loss: 1.5740 - val_accuracy: 0.8562 - val_loss: 0.4952
# Epoch 146/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8407 - loss: 1.5712 - val_accuracy: 0.8569 - val_loss: 0.4941
# Epoch 147/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8414 - loss: 1.5684 - val_accuracy: 0.8573 - val_loss: 0.4935
# Epoch 148/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8420 - loss: 1.5655 - val_accuracy: 0.8575 - val_loss: 0.4927
# Epoch 149/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8422 - loss: 1.5629 - val_accuracy: 0.8579 - val_loss: 0.4918
# Epoch 150/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8428 - loss: 1.5602 - val_accuracy: 0.8581 - val_loss: 0.4911

# %%
# Training Loss plot
loss_values = history.history['loss']
epochs = range(1, len(loss_values)+1)

plt.plot(epochs, loss_values, label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
#plt.ylim(0, 10)
plt.legend()

plt.show()

# %%
# Prediction confusion matrix
y_prediction = model.predict(x_test)
y_prediction = np.argmax(y_prediction, axis = 1)
y_test_pred = np.argmax(y_test, axis=1)


# Create confusion matrix and normalize it over predicted (columns)
#result = confusion_matrix(y_test_pred, y_prediction , normalize='pred')
result = confusion_matrix(y_test_pred, y_prediction , normalize='true')
#result = confusion_matrix(y_test_pred, y_prediction , normalize='all')
#result = confusion_matrix(y_test_pred, y_prediction)
classes = [0,1,2,3,4]
result_norm = np.around(result, 3)
#result_norm = result
mat_result = pd.DataFrame(result_norm,
                     index = classes, 
                     columns = classes)

total_pred = np.trace(result) / 5

print('Confusion matrix')
print(mat_result)
print()
print('Average accuracy')
print(total_pred)
# Out:
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Confusion matrix
#        0      1      2      3      4
# 0  0.845  0.081  0.024  0.035  0.015
# 1  0.123  0.848  0.004  0.009  0.015
# 2  0.030  0.024  0.899  0.033  0.014
# 3  0.134  0.016  0.024  0.827  0.000
# 4  0.023  0.017  0.012  0.003  0.945
#
# Average accuracy
# 0.8727353523391816

# %%
# Print detailed results
target_names = ['class 0', 'class 1', 'class 2', 'class 3', 'class 4']
print(classification_report(y_test_pred, y_prediction, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.99      0.85      0.91     14455
#      class 1       0.24      0.85      0.37       455
#      class 2       0.74      0.90      0.81      1184
#      class 3       0.16      0.83      0.27       127
#      class 4       0.83      0.94      0.88      1283
#
#     accuracy                           0.86     17504
#    macro avg       0.59      0.87      0.65     17504
# weighted avg       0.94      0.86      0.88     17504

# %%
model_num = 0
#while os.path.exists(MODEL_PATH_BASE + MODEL_NAME_BASE + "%s.keras" % f"{model_num:02}"):
#    model_num += 1
log_dir = LOG_DIR
#model_name = MODEL_NAME_BASE+ str(f"{model_num:02}")
model_name = MODEL_NAME_BASE+ str(f"{NEURONS:02}")
model_path = MODEL_PATH_BASE + model_name + '.keras'
model.name = model_name
#model.save(model_path)

# %%
model_name = "mlp_beat"+str(f"{HEARTBEAT_LENGTH:03}")+"_rand"+str(f"{POINTS_LENGTH:03}")+"_n"+str(f"{NEURONS:02}")

# %%
figure = plt.figure(figsize=(4, 4))
sns.heatmap(mat_result, annot=True,cmap=plt.cm.Blues)
plt.title(model_name)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.tight_layout()
#plt.savefig(log_dir + '/' + model_name + '.png', pad_inches=0.1)
plt.show()
