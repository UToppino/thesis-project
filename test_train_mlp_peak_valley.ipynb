# %% [markdown]
# ## MLP + peak/valley classification
# Extract heartbeats from raw dataset and trains an MLP for classification:
# - Extract all usable heartbeats of fixed length from the raw data
# - Uses the peak/valley algorithm to extract N peak amplitudes
# - Trains an MLP network on the selected peaks

# %%
# Importing packages
import copy
import datetime
import numpy as np
import pandas as pd
import random
import seaborn as sns
import matplotlib.pyplot as plt
import math
from scipy import signal
import keras
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
import keras
import keras_tuner as kt
from keras.utils import to_categorical
from keras.layers import Dense, Convolution1D, Convolution2D, MaxPool1D, Flatten, Dropout, AveragePooling1D
from keras.layers import Input
from keras import initializers
from keras.models import Model, Sequential
from keras.layers import BatchNormalization
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.utils import class_weight
from sklearn.utils import resample
import warnings
import wfdb
import os
import tensorflow as tf
warnings.filterwarnings('ignore')

# %%
### PARAMETERS TO SET ###

# Balance the weight of the different classes of the (unbalanced) dataset
CUSTOM_WEIGHTS = True

# Parameters for heartbeat extraction
# Number of samples to consider as the length of an heartbeat
HEARTBEAT_LENGTH = 400
# Number of random points to extract from heartbeat
POINTS_LENGTH = 32

# Parameters for float to integer conversion
# 16bits max and min values
INT_RANGE = 65536
INT_LOW = -32768
INT_HIGH = 32767
# Wether to convert down to 8bit or stay at 16bit
CONV_8BIT = True
print("Range: "+str(INT_RANGE)+"   MIN: "+str(INT_LOW)+"   MAX:"+str(INT_HIGH))

# Parameters for saving files
# Confusion matrix img is saved in LOG_DIR
# Model is stored in MODEL_PATH_BASE with name MODEL_NAME_BASE plus two digits
LOG_DIR = "logs/mlp_only/"
MODEL_NAME_BASE = 'mlp_only_'
MODEL_PATH_BASE = 'models/mlp_only/'
# Out:
# Range: 65536   MIN: -32768   MAX:32767

# %%
# Parameters for determinism
KERAS_SEED = 1234509876
keras.utils.set_random_seed(KERAS_SEED)
tf.config.experimental.enable_op_determinism()

# %%
### Extract data from files
mitdb_list = [100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 111, 112, 113, 114, 115, 116, 117, 118, 119, 121, 122, 123, 124, 200, 201, 202, 203, 205, 207, 208, 209, 210, 212, 213, 214, 215, 217, 219, 220, 221, 222, 223, 228, 230, 231, 232, 233, 234]

if CONV_8BIT:
    v_dataset_data = np.empty((1,HEARTBEAT_LENGTH), dtype=np.int8)
else:
    v_dataset_data = np.empty((1,HEARTBEAT_LENGTH), dtype=np.int16)

# Float dataset
v_dataset_data = np.empty((1,HEARTBEAT_LENGTH), dtype=float)
v_dataset_categ = np.empty(1, dtype=str)

v_data_min = 10.0
v_data_max = -10.0

for element in mitdb_list:
    record = wfdb.rdrecord('src/mitdb/' + str(element))
    v_data_min = np.min(record.p_signal) if np.min(record.p_signal) < v_data_min else v_data_min
    v_data_max = np.max(record.p_signal) if np.max(record.p_signal) > v_data_max else v_data_max

v_data_abs_max = np.max(np.abs([v_data_min, v_data_max]))

print("MAX: " + str(v_data_max) + "   MIN: " + str(v_data_min))
print("ABS MAX: " +str(v_data_abs_max))

for element in mitdb_list:


    print("##########")
    print("Current record: " + str(element))

    # Load all samples
    record = wfdb.rdrecord('src/mitdb/' + str(element))
    annotation = wfdb.rdann('src/mitdb/'+str(element), 'atr')

    # Convert annotations to useful ones
    # Read symbols and substitute them
    # Classes:  'N': Normal beat
    #           'S': Supraventricular premature
    #           'V': Premature ventricular contraction
    #           'F': Fusion of ventricular and normal beat
    #           'Q': Unclassifiable
    #
    # CLASSIFICATION
    # Based on the paper "A deep convolutional neural network model to classify heartbeats"
    symbol_dict = { 'N':'N', 'L':'N', 'R':'N', 'e':'N', 'j':'N',
                    'S':'S', 'A':'S', 'a':'S', 'J':'S',
                    'V':'V', 'E':'V',
                    'F':'F',
                    'Q':'Q', '/':'Q', 'f':'Q'}
    raw_ann_symbol = annotation.symbol.copy()
    raw_ann_sample = annotation.sample.copy()
    #raw_ann_symbol = [symbol_dict[key] if key in symbol_dict else key for key in raw_ann_symbol]
    raw_ann_symbol = [symbol_dict[key] if key in symbol_dict else 'Z' for key in raw_ann_symbol]

    # Delete non beat annotations
    if 'Z' in raw_ann_symbol:
        i_del = [i for i, x in enumerate(raw_ann_symbol) if x == 'Z']
        raw_ann_sample = np.delete(raw_ann_sample, i_del)
        raw_ann_symbol = np.delete(raw_ann_symbol, i_del)

    # Extract ECG data array
    v_data_f = record.p_signal
    v_data_f = v_data_f[:,0]

    # Convert data from float to uint16
    #v_data = np.zeros_like(v_data_f, dtype=np.int16)
    #for i in range(0, len(v_data_f)):
    #    # Offset and scale
    #    #v_data[i] = ((v_data_f[i]-v_data_min)/(v_data_max - v_data_min))*(INT_RANGE)+(INT_LOW)
    #    # Scale only
    #    v_data[i] = np.int16((v_data_f[i])/(v_data_abs_max)*(INT_HIGH))
    #    if CONV_8BIT:
    #        v_data[i] = np.int8((v_data[i] >> 8) & 0xFF)

    # If using float instead of int
    #v_data = v_data_f/v_data_abs_max*INT_HIGH
    v_data = v_data_f

    print(v_data_f)
    print(v_data)

    # Define time array (Fs:360Hz)
    v_time = np.arange(0, HEARTBEAT_LENGTH, 1, dtype=int)

    # Zeros array for x-axis
    axis_x = np.zeros_like(v_time)

    # Delete annotations for beats too close to the beginning or ending of signal
    raw_ann_symbol = raw_ann_symbol[(raw_ann_sample > (HEARTBEAT_LENGTH/2+1)) & (raw_ann_sample < (len(v_data)-(HEARTBEAT_LENGTH/2+1)))]
    raw_ann_sample = raw_ann_sample[(raw_ann_sample > (HEARTBEAT_LENGTH/2+1)) & (raw_ann_sample < (len(v_data)-(HEARTBEAT_LENGTH/2+1)))]

    print(raw_ann_symbol)
    print(raw_ann_sample)
    print(len(raw_ann_symbol))
    print(len(raw_ann_sample))
    
    # Divide signal in single heartbeats
    v_total_data = np.zeros(shape=(len(raw_ann_symbol),HEARTBEAT_LENGTH))
    v_total_categ = np.empty(len(raw_ann_symbol), dtype=str)
    for i in range(0, len(v_total_data)-1):
        v_total_data[i,:] = v_data[(raw_ann_sample[i] - int(HEARTBEAT_LENGTH/2)) : (raw_ann_sample[i] + int(HEARTBEAT_LENGTH/2))]
        v_total_categ[i] = raw_ann_symbol[i]
        #print(v_total_data[i,:])

    # Delete empty data
    v_total_data = v_total_data[v_total_categ != '']
    v_total_categ = v_total_categ[v_total_categ != '']

    # Copy results to dataset variables
    v_dataset_data = np.append(v_dataset_data, v_total_data, axis=0)
    v_dataset_categ = np.append(v_dataset_categ, v_total_categ)

# Delete first element (empty)
v_dataset_data = v_dataset_data[1:,:]
v_dataset_categ = v_dataset_categ[1:]

print(v_dataset_categ)
print(v_dataset_data)
# Out:
# MAX: 5.115   MIN: -5.12
# ABS MAX: 5.12
# ##########
# Current record: 100
# [-0.145 -0.145 -0.145 ... -0.675 -0.765 -1.28 ]
# [-0.145 -0.145 -0.145 ... -0.675 -0.765 -1.28 ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   370    662    946 ... 649232 649484 649734]
# 2271
# 2271
# ##########
# Current record: 101
# [-0.345 -0.345 -0.345 ... -0.295 -0.29   0.   ]
# [-0.345 -0.345 -0.345 ... -0.295 -0.29   0.   ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   396    711   1032 ... 649004 649372 649751]
# 1864
# 1864
# ##########
# Current record: 102
# [-0.2   -0.2   -0.2   ... -0.17  -0.195  0.   ]
# [-0.2   -0.2   -0.2   ... -0.17  -0.195  0.   ]
# ['Q' 'Q' 'Q' ... 'Q' 'Q' 'Q']
# [   410    697    989 ... 648931 649244 649553]
# 2185
# 2185
# ##########
# Current record: 103
# [-0.375 -0.375 -0.375 ... -0.235 -0.245  0.   ]
# [-0.375 -0.375 -0.375 ... -0.235 -0.245  0.   ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   265    575    876 ... 648872 649195 649534]
# 2083
# 2083
# ##########
# Current record: 104
# [-0.15  -0.15  -0.15  ... -0.065 -0.06   0.   ]
# [-0.15  -0.15  -0.15  ... -0.065 -0.06   0.   ]
# ['Q' 'Q' 'Q' ... 'Q' 'Q' 'Q']
# [   316    615    901 ... 649022 649300 649580]
# 2227
# 2227
# ##########
# Current record: 105
# [-0.445 -0.445 -0.445 ...  0.59   0.76   1.28 ]
# [-0.445 -0.445 -0.445 ...  0.59   0.76   1.28 ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   459    708    965 ... 649221 649471 649740]
# 2571
# 2571
# ##########
# Current record: 106
# [-0.31  -0.31  -0.31  ...  0.635  0.265  0.   ]
# [-0.31  -0.31  -0.31  ...  0.635  0.265  0.   ]
# ['N' 'N' 'N' ... 'V' 'V' 'N']
# [   351    724   1086 ... 649162 649340 649791]
# 2027
# 2027
# ##########
# Current record: 107
# [-2.045 -2.045 -2.045 ... -0.645 -0.635  0.   ]
# [-2.045 -2.045 -2.045 ... -0.645 -0.635  0.   ]
# ['Q' 'Q' 'Q' ... 'Q' 'Q' 'Q']
# [   272    569    884 ... 649129 649441 649748]
# 2136
# 2136
# ##########
# Current record: 108
# [-0.125 -0.125 -0.125 ... -0.01   0.04   0.   ]
# [-0.125 -0.125 -0.125 ... -0.01   0.04   0.   ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   442    789   1155 ... 649170 649471 649769]
# 1762
# 1762
# ##########
# Current record: 109
# [ 0.175  0.175  0.175 ... -0.92  -0.91  -1.28 ]
# [ 0.175  0.175  0.175 ... -0.92  -0.91  -1.28 ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   343    571    807 ... 649109 649378 649663]
# 2530
# 2530
# ##########
# Current record: 111
# [-0.035 -0.035 -0.035 ...  0.155  0.2    0.   ]
# [-0.035 -0.035 -0.035 ...  0.155  0.2    0.   ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   489    804   1127 ... 649148 649441 649724]
# 2123
# 2123
# ##########
# Current record: 112
# [-0.75  -0.75  -0.75  ... -0.825 -0.81  -1.28 ]
# [-0.75  -0.75  -0.75  ... -0.825 -0.81  -1.28 ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   382    644    892 ... 649105 649361 649626]
# 2537
# 2537
# ##########
# Current record: 113
# [-0.46 -0.46 -0.46 ...  1.06  0.42  0.  ]
# [-0.46 -0.46 -0.46 ...  1.06  0.42  0.  ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   583    966   1326 ... 649008 649364 649675]
# 1793
# 1793
# ##########
# Current record: 114
# [-0.045 -0.045 -0.045 ... -0.365 -0.37   0.   ]
# [-0.045 -0.045 -0.045 ... -0.365 -0.37   0.   ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   310    726   1143 ... 649261 649523 649783]
# 1879
# 1879
# ##########
# Current record: 115
# [-0.58 -0.58 -0.58 ... -0.75 -0.75 -1.28]
# [-0.58 -0.58 -0.58 ... -0.75 -0.75 -1.28]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   518    850   1211 ... 649055 649357 649647]
# 1951
# 1951
# ##########
# Current record: 116
# [-0.32  -0.32  -0.32  ... -0.975 -0.96  -1.28 ]
# [-0.32  -0.32  -0.32  ... -0.975 -0.96  -1.28 ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   282    561    837 ... 649191 649442 649701]
# 2411
# 2411
# ##########
# Current record: 117
# [-0.925 -0.925 -0.925 ... -0.585 -0.565  0.   ]
# [-0.925 -0.925 -0.925 ... -0.585 -0.565  0.   ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   598   1006   1408 ... 648653 649070 649498]
# 1533
# 1533
# ##########
# Current record: 118
# [-0.835 -0.835 -0.835 ...  0.03   0.085  0.   ]
# [-0.835 -0.835 -0.835 ...  0.03   0.085  0.   ]
# ['N' 'N' 'N' ... 'N' 'S' 'N']
# [   369    674    980 ... 649226 649429 649742]
# 2277
# 2277
# ##########
# Current record: 119
# [-0.995 -0.995 -0.995 ...  1.565  1.525  1.28 ]
# [-0.995 -0.995 -0.995 ...  1.565  1.525  1.28 ]
# ['N' 'V' 'N' ... 'N' 'N' 'N']
# [   309    503    977 ... 649129 649468 649788]
# 1987
# 1987
# ##########
# Current record: 121
# [-0.875 -0.875 -0.875 ... -0.86  -0.875 -1.28 ]
# [-0.875 -0.875 -0.875 ... -0.86  -0.875 -1.28 ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   513    874   1217 ... 648996 649287 649587]
# 1861
# 1861
# ##########
# Current record: 122
# [-0.78 -0.78 -0.78 ... -1.02 -1.04 -1.28]
# [-0.78 -0.78 -0.78 ... -1.02 -1.04 -1.28]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   326    561    798 ... 649126 649383 649643]
# 2474
# 2474
# ##########
# Current record: 123
# [-0.805 -0.805 -0.805 ... -1.25  -1.225 -1.28 ]
# [-0.805 -0.805 -0.805 ... -1.25  -1.225 -1.28 ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   550   1021   1498 ... 648997 649342 649689]
# 1517
# 1517
# ##########
# Current record: 124
# [-1.    -1.    -1.    ... -0.72  -0.705 -1.28 ]
# [-1.    -1.    -1.    ... -0.72  -0.705 -1.28 ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   243    693   1119 ... 648786 649146 649510]
# 1618
# 1618
# ##########
# Current record: 200
# [0.35  0.35  0.35  ... 0.015 0.015 0.   ]
# [0.35  0.35  0.35  ... 0.015 0.015 0.   ]
# ['V' 'N' 'V' ... 'N' 'N' 'N']
# [   225    487    689 ... 649161 649408 649664]
# 2600
# 2600
# ##########
# Current record: 201
# [-0.26 -0.26 -0.26 ... -0.17 -0.18  0.  ]
# [-0.26 -0.26 -0.26 ... -0.17 -0.18  0.  ]
# ['N' 'N' 'N' ... 'N' 'S' 'N']
# [   415    686    905 ... 648419 648594 649104]
# 1961
# 1961
# ##########
# Current record: 202
# [ 0.    0.    0.   ... -0.24 -0.24  0.  ]
# [ 0.    0.    0.   ... -0.24 -0.24  0.  ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   348    742   1155 ... 649092 649342 649615]
# 2135
# 2135
# ##########
# Current record: 203
# [-0.26 -0.26 -0.26 ... -0.55 -0.52  0.  ]
# [-0.26 -0.26 -0.26 ... -0.55 -0.52  0.  ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   431    660    862 ... 649237 649448 649777]
# 2979
# 2979
# ##########
# Current record: 205
# [-0.43  -0.43  -0.43  ... -0.365 -0.375  0.   ]
# [-0.43  -0.43  -0.43  ... -0.365 -0.375  0.   ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   229    466    706 ... 649060 649326 649596]
# 2655
# 2655
# ##########
# Current record: 207
# [-0.215 -0.215 -0.215 ... -1.19  -1.135 -1.28 ]
# [-0.215 -0.215 -0.215 ... -1.19  -1.135 -1.28 ]
# ['V' 'N' 'V' ... 'S' 'S' 'S']
# [   312    835   1078 ... 649262 649431 649602]
# 1858
# 1858
# ##########
# Current record: 208
# [-0.105 -0.105 -0.105 ... -0.17  -0.16   0.   ]
# [-0.105 -0.105 -0.105 ... -0.17  -0.16   0.   ]
# ['V' 'N' 'F' ... 'N' 'V' 'N']
# [   209    483    697 ... 649206 649411 649704]
# 2953
# 2953
# ##########
# Current record: 209
# [-0.02  -0.02  -0.02  ... -0.265 -0.28   0.   ]
# [-0.02  -0.02  -0.02  ... -0.265 -0.28   0.   ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   425    659    889 ... 649149 649387 649627]
# 3003
# 3003
# ##########
# Current record: 210
# [-0.065 -0.065 -0.065 ... -0.305 -0.3    0.   ]
# [-0.065 -0.065 -0.065 ... -0.305 -0.3    0.   ]
# ['N' 'N' 'V' ... 'N' 'V' 'N']
# [   250    471    625 ... 649216 649513 649758]
# 2648
# 2648
# ##########
# Current record: 212
# [-0.5  -0.5  -0.5  ... -0.34 -0.33  0.  ]
# [-0.5  -0.5  -0.5  ... -0.34 -0.33  0.  ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   214    451    696 ... 649141 649414 649673]
# 2747
# 2747
# ##########
# Current record: 213
# [-0.01  -0.01  -0.01  ...  1.135  0.715  1.28 ]
# [-0.01  -0.01  -0.01  ...  1.135  0.715  1.28 ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   253    478    673 ... 649374 649577 649790]
# 3249
# 3249
# ##########
# Current record: 214
# [-0.095 -0.095 -0.095 ... -0.32  -0.285  0.   ]
# [-0.095 -0.095 -0.095 ... -0.32  -0.285  0.   ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   346    660    975 ... 649112 649379 649627]
# 2260
# 2260
# ##########
# Current record: 215
# [ 0.22   0.22   0.22  ... -0.285 -0.28   0.   ]
# [ 0.22   0.22   0.22  ... -0.285 -0.28   0.   ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   313    503    704 ... 649304 649501 649685]
# 3361
# 3361
# ##########
# Current record: 217
# [ 0.045  0.045  0.045 ... -0.36  -0.33   0.   ]
# [ 0.045  0.045  0.045 ... -0.36  -0.33   0.   ]
# ['Q' 'Q' 'Q' ... 'Q' 'Q' 'Q']
# [   205    500    812 ... 649114 649429 649738]
# 2208
# 2208
# ##########
# Current record: 219
# [-0.695 -0.695 -0.695 ... -0.89  -0.885 -1.28 ]
# [-0.695 -0.695 -0.695 ... -0.89  -0.885 -1.28 ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   300    614    887 ... 649174 649448 649737]
# 2154
# 2154
# ##########
# Current record: 220
# [-0.69  -0.69  -0.69  ... -0.16  -0.155  0.   ]
# [-0.69  -0.69  -0.69  ... -0.16  -0.155  0.   ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   313    612    916 ... 648966 649277 649584]
# 2046
# 2046
# ##########
# Current record: 221
# [-0.285 -0.285 -0.285 ... -0.235 -0.245  0.   ]
# [-0.285 -0.285 -0.285 ... -0.235 -0.245  0.   ]
# ['N' 'N' 'V' ... 'N' 'N' 'N']
# [   220    442    603 ... 648982 649236 649530]
# 2426
# 2426
# ##########
# Current record: 222
# [-0.14 -0.14 -0.14 ... -0.27 -0.28  0.  ]
# [-0.14 -0.14 -0.14 ... -0.27 -0.28  0.  ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   361    646    892 ... 649157 649317 649600]
# 2481
# 2481
# ##########
# Current record: 223
# [-0.93  -0.93  -0.93  ... -0.55  -0.555  0.   ]
# [-0.93  -0.93  -0.93  ... -0.55  -0.555  0.   ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   204    480    759 ... 649091 649349 649599]
# 2604
# 2604
# ##########
# Current record: 228
# [-0.155 -0.155 -0.155 ... -0.29  -0.285  0.   ]
# [-0.155 -0.155 -0.155 ... -0.29  -0.285  0.   ]
# ['N' 'N' 'N' ... 'N' 'V' 'N']
# [   433    726   1061 ... 649108 649332 649761]
# 2052
# 2052
# ##########
# Current record: 230
# [-0.38 -0.38 -0.38 ... -0.59 -0.59  0.  ]
# [-0.38 -0.38 -0.38 ... -0.59 -0.59  0.  ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   349    616    880 ... 649106 649338 649572]
# 2254
# 2254
# ##########
# Current record: 231
# [-0.2  -0.2  -0.2  ...  0.34  0.34  0.  ]
# [-0.2  -0.2  -0.2  ...  0.34  0.34  0.  ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   527    847   1166 ... 648811 649142 649501]
# 1569
# 1569
# ##########
# Current record: 232
# [-0.245 -0.245 -0.245 ... -0.07  -0.075  0.   ]
# [-0.245 -0.245 -0.245 ... -0.07  -0.075  0.   ]
# ['N' 'S' 'S' ... 'N' 'S' 'S']
# [   491    737   1000 ... 648845 649097 649366]
# 1780
# 1780
# ##########
# Current record: 233
# [-0.095 -0.095 -0.095 ... -0.495 -0.49   0.   ]
# [-0.095 -0.095 -0.095 ... -0.495 -0.49   0.   ]
# ['N' 'V' 'N' ... 'V' 'N' 'N']
# [   320    511    749 ... 649237 649518 649730]
# 3077
# 3077
# ##########
# Current record: 234
# [-0.08  -0.08  -0.08  ... -0.395 -0.38   0.   ]
# [-0.08  -0.08  -0.08  ... -0.395 -0.38   0.   ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   366    606    841 ... 649292 649536 649772]
# 2752
# 2752
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [[-0.365 -0.36  -0.37  ... -0.335 -0.345 -0.35 ]
#  [-0.45  -0.435 -0.445 ... -0.36  -0.355 -0.36 ]
#  [-0.41  -0.415 -0.42  ... -0.35  -0.355 -0.345]
#  ...
#  [-0.35  -0.335 -0.325 ... -0.17  -0.17  -0.155]
#  [-0.34  -0.345 -0.35  ... -0.055 -0.07  -0.065]
#  [-0.385 -0.39  -0.395 ... -0.065 -0.06  -0.055]]

# %%
# Extract N random numbers from heartbeat
random_indices = np.random.choice(HEARTBEAT_LENGTH, size=POINTS_LENGTH, replace=False)
random_indices = np.sort(random_indices)
v_dataset_data_rand = [arr[random_indices] for arr in v_dataset_data]
#print(v_dataset_data)
#print(random_indices)

# %%
# Apply peak/valley algorith to all heartbeats
# Identify potential peaks
# Compare 3 signal samples S0, S1, S2
# Peak if:  S1>S0 and S1>S2
#           S1<S0 and S1<S2

FREQ_SAMPLE = 360

DELTA_PEAK = 0.04
#DELTA_TIME = 75/FREQ_SAMPLE     # Number of samples / Sampling frequency
DELTA_TIME = 15

v_peaks_data = np.zeros_like(v_dataset_data)
v_peaks_time = np.zeros_like(v_dataset_data, dtype=int)

print(v_peaks_data.shape)

for n in range(len(v_dataset_data)):
    j = 0
    # Walk through all samples
    for i in range(1, len(v_dataset_data[n])-1):
        # Identify peak
        if  ((v_dataset_data[n][i] >= v_dataset_data[n][i-1]) and (v_dataset_data[n][i] > v_dataset_data[n][i+1])) or \
            ((v_dataset_data[n][i] <= v_dataset_data[n][i-1]) and (v_dataset_data[n][i] < v_dataset_data[n][i+1])):
            # Check if peak value big enough
            if  (abs(v_dataset_data[n][i] - v_peaks_data[n][j-1]) > DELTA_PEAK) or \
                (abs(v_time[i] - v_peaks_time[n][j-1]) > DELTA_TIME):
                v_peaks_data[n][j] = v_dataset_data[n][i]
                v_peaks_time[n][j] = v_time[i]
                j += 1
                

    #v_peaks_data = v_peaks_data[v_peaks_time != 0]
    #v_peaks_time = v_peaks_time[v_peaks_time != 0]
# Out:
# (109381, 400)

# %%
# Select useful peaks and valleys for training

low_time = np.zeros(shape=int(POINTS_LENGTH/2), dtype=int)
high_time = np.zeros(shape=int(POINTS_LENGTH/2), dtype=int)
points_time = np.zeros(shape=(len(v_peaks_time), POINTS_LENGTH), dtype=int)
points_data = np.zeros(shape=(len(v_peaks_time), POINTS_LENGTH))

for n in range(len(v_peaks_time)):
    #print("n: "+str(n))
    # Split array in half
    low_time_tmp = v_peaks_time[n][v_peaks_time[n] <= int(HEARTBEAT_LENGTH/2)]
    high_time_tmp = v_peaks_time[n][v_peaks_time[n] > int(HEARTBEAT_LENGTH/2)]

    low_time_tmp = low_time_tmp[low_time_tmp != 0]
    high_time_tmp = high_time_tmp[high_time_tmp != 0]
    #print("low_time_tmp1: "+str(low_time_tmp))

    # Select correct number of points from each half
    low_time_tmp = low_time_tmp[-int(POINTS_LENGTH/2):]
    high_time_tmp = high_time_tmp[:int(POINTS_LENGTH/2)]
    #print("low_time_tmp2: "+str(low_time_tmp))

    # Check if the correct number of points were selected
    if len(low_time_tmp) > 0:
        low_time[-len(low_time_tmp):] = low_time_tmp
    else:
        low_time = np.zeros(shape=int(POINTS_LENGTH/2), dtype=int)
    if len(high_time_tmp) > 0:
        high_time[:len(high_time_tmp):] = high_time_tmp
    else:
        high_time = np.zeros(shape=int(POINTS_LENGTH/2), dtype=int)

    # Copy points to final arrays
    points_time[n] = np.append(low_time, high_time)
    points_data[n] = v_dataset_data[n][points_time[n]]

    
    #print("points_time[n]: "+str(points_time[n]))
    #print("points_data[n]: "+str(points_data[n]))

# %%
# Backup dataset to other variable

### All points
#v_dataset_data_bk = np.copy(v_dataset_data)
### Random selection of points
#v_dataset_data_bk = np.copy(v_dataset_data_rand)
### Peak/valley
v_dataset_data_bk = np.copy(points_data)


v_dataset_categ_bk = np.copy(v_dataset_categ)

# %%
# Plotting window
X_MIN = 0
X_MAX = 400
N_ROW = 5
N_COL = 1
PLOT_LOW = INT_LOW
PLOT_HIGH = INT_HIGH

if CONV_8BIT:
    PLOT_LOW = -128
    PLOT_HIGH = 127

n = 0
# Create plots
fig, axs = plt.subplots(N_ROW, N_COL, sharex=True)
fig.set_size_inches(15, 3*N_ROW)
fig.suptitle("ECG Signal conditioning")
axs[n].set_xlim(X_MIN, X_MAX)

for n in range(0, N_ROW):
    # First plot
    rand = random.randint(0, points_time.shape[0])
    axs[n].title.set_text('Plot')
    axs[n].plot(v_dataset_data[rand], 'b', label="raw data", linewidth=0.5)
    axs[n].plot(points_time[rand], points_data[rand], 'r.', label="raw data", linewidth=0.5)
    #n += 1



# First plot
#axs[n].title.set_text('Plot')
#axs[n].plot(v_time, axis_x, linewidth=0.2, color="black")
#axs[n].plot(v_time, v_dataset_data[n], 'b', label="raw data", linewidth=0.5)
#axs[n].legend()
#n += 1

# First plot
#axs[n].title.set_text('Plot')
#axs[n].plot(v_time, axis_x, linewidth=0.2, color="black")
#axs[n].plot(v_time, v_data, 'b', label="raw data", linewidth=0.5)
#axs[n].plot(v_peaks_R_time, v_peaks_R_data, 'mo', label="R peaks", linewidth=0.5)
#axs[n].plot(v_peaks_P_time, v_peaks_P_data, 'bo', label="P peaks", linewidth=0.5)
#axs[n].plot(v_peaks_T_time, v_peaks_T_data, 'ro', label="T peaks", linewidth=0.5)
#axs[n].legend()
#n += 1

plt.tight_layout()
plt.show()

# %%
#stop

# %%
# Copy from backup data
dataset_categ = np.copy(v_dataset_categ_bk)
dataset_data = np.copy(v_dataset_data_bk)

# Convert symbols to numbers
category_dict = {   'N':0,
                    'S':1,
                    'V':2,
                    'F':3,
                    'Q':4}
dataset_categ = [category_dict[key] if key in category_dict else 'Z' for key in dataset_categ]

# Divide data into sets
DATA_SPLIT = 0.2
SEED = 1029384756
set_train, x_valid, target_train, y_valid = train_test_split(dataset_data, dataset_categ, test_size=DATA_SPLIT, random_state=SEED)
x_train, x_test, y_train, y_test = train_test_split(set_train, target_train, test_size=DATA_SPLIT, random_state=SEED)

y_train=to_categorical(y_train)
y_test=to_categorical(y_test)
y_valid=to_categorical(y_valid)

# %%
# Calculate cutom weights for training
tot_y_train = np.sum(y_train, axis=0)
tot_y_test = np.sum(y_test, axis=0)
tot_y_valid = np.sum(y_valid, axis=0)
tot_y_all = tot_y_train + tot_y_test + tot_y_valid

print(tot_y_train)
print(tot_y_test)
print(tot_y_valid)
print(tot_y_all)

max_class = np.max(tot_y_train)
#max_class = np.sum(tot_y_train)

custom_weights = {  0: int(max_class/tot_y_train[0]),
                    1: int(max_class/tot_y_train[1]),
                    2: int(max_class/tot_y_train[2]),
                    3: int(max_class/tot_y_train[3]),
                    4: int(max_class/tot_y_train[4])}

print(custom_weights)
# Out:
# [57974.  1776.  4643.   520.  5090.]
# [14483.   485.  1093.   118.  1322.]
# [18075.   517.  1499.   164.  1622.]
# [90532.  2778.  7235.   802.  8034.]
# {0: 1, 1: 32, 2: 12, 3: 111, 4: 11}

# %%
# Define NN structure
NEURONS = 20
LEARNING_RATE = 0.0001
model = Sequential([
    Input(shape=((x_train[0].shape[0],1)), name='inputs_nn'),
    Flatten(),    
    # Custom initial weights for deterministic behavior
    Dense(NEURONS, activation='relu', name="dense_1", kernel_initializer=initializers.GlorotUniform(seed=KERAS_SEED), bias_initializer='zeros'),
    Dense(5, activation='softmax', name='main_output', kernel_initializer=initializers.GlorotUniform(seed=KERAS_SEED), bias_initializer='zeros') 
])

model.compile(optimizer=keras.optimizers.Adam(learning_rate=LEARNING_RATE), loss='categorical_crossentropy',metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_8 (Flatten)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 20)             │           660 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ main_output (Dense)             │ (None, 5)              │           105 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 765 (2.99 KB)
#  Trainable params: 765 (2.99 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Training parameters
EPOCH_NUM = 150
BATCH_SIZE = 64

# Train model
if (CUSTOM_WEIGHTS):
    history=model.fit(x_train, y_train, epochs=EPOCH_NUM, batch_size=BATCH_SIZE, validation_data=(x_valid,y_valid), class_weight=custom_weights)
else:
    history=model.fit(x_train, y_train, epochs=EPOCH_NUM, batch_size=BATCH_SIZE, validation_data=(x_valid,y_valid))
# Out:
# Epoch 1/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.6882 - loss: 6.7212 - val_accuracy: 0.5694 - val_loss: 1.3567
# Epoch 2/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5545 - loss: 5.9581 - val_accuracy: 0.4981 - val_loss: 1.3326
# Epoch 3/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.4866 - loss: 5.4795 - val_accuracy: 0.4310 - val_loss: 1.3098
# Epoch 4/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.4233 - loss: 5.1053 - val_accuracy: 0.3929 - val_loss: 1.2869
# Epoch 5/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.3954 - loss: 4.8049 - val_accuracy: 0.3823 - val_loss: 1.2635
# Epoch 6/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.3886 - loss: 4.5623 - val_accuracy: 0.3832 - val_loss: 1.2389
# Epoch 7/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3903 - loss: 4.3631 - val_accuracy: 0.3860 - val_loss: 1.2170
# Epoch 8/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.3923 - loss: 4.1999 - val_accuracy: 0.3909 - val_loss: 1.1974
# Epoch 9/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.3976 - loss: 4.0634 - val_accuracy: 0.3949 - val_loss: 1.1802
# Epoch 10/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.4043 - loss: 3.9453 - val_accuracy: 0.4040 - val_loss: 1.1619
# Epoch 11/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.4135 - loss: 3.8413 - val_accuracy: 0.4126 - val_loss: 1.1479
# Epoch 12/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.4230 - loss: 3.7482 - val_accuracy: 0.4251 - val_loss: 1.1334
# Epoch 13/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.4355 - loss: 3.6638 - val_accuracy: 0.4371 - val_loss: 1.1185
# Epoch 14/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.4513 - loss: 3.5863 - val_accuracy: 0.4513 - val_loss: 1.1047
# Epoch 15/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.4660 - loss: 3.5141 - val_accuracy: 0.4647 - val_loss: 1.0917
# Epoch 16/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.4796 - loss: 3.4460 - val_accuracy: 0.4765 - val_loss: 1.0780
# Epoch 17/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.4933 - loss: 3.3831 - val_accuracy: 0.4924 - val_loss: 1.0636
# Epoch 18/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.5074 - loss: 3.3256 - val_accuracy: 0.5060 - val_loss: 1.0502
# Epoch 19/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.5226 - loss: 3.2724 - val_accuracy: 0.5207 - val_loss: 1.0371
# Epoch 20/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.5365 - loss: 3.2229 - val_accuracy: 0.5341 - val_loss: 1.0245
# Epoch 21/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.5497 - loss: 3.1764 - val_accuracy: 0.5451 - val_loss: 1.0124
# Epoch 22/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.5616 - loss: 3.1324 - val_accuracy: 0.5556 - val_loss: 1.0010
# Epoch 23/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.5717 - loss: 3.0910 - val_accuracy: 0.5645 - val_loss: 0.9905
# Epoch 24/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5806 - loss: 3.0518 - val_accuracy: 0.5742 - val_loss: 0.9791
# Epoch 25/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.5889 - loss: 3.0145 - val_accuracy: 0.5811 - val_loss: 0.9691
# Epoch 26/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.5970 - loss: 2.9791 - val_accuracy: 0.5881 - val_loss: 0.9599
# Epoch 27/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6041 - loss: 2.9455 - val_accuracy: 0.5956 - val_loss: 0.9504
# Epoch 28/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.6105 - loss: 2.9134 - val_accuracy: 0.6025 - val_loss: 0.9409
# Epoch 29/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6164 - loss: 2.8827 - val_accuracy: 0.6076 - val_loss: 0.9329
# Epoch 30/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.6219 - loss: 2.8533 - val_accuracy: 0.6129 - val_loss: 0.9251
# Epoch 31/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.6276 - loss: 2.8251 - val_accuracy: 0.6194 - val_loss: 0.9175
# Epoch 32/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.6331 - loss: 2.7979 - val_accuracy: 0.6244 - val_loss: 0.9109
# Epoch 33/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6384 - loss: 2.7716 - val_accuracy: 0.6290 - val_loss: 0.9036
# Epoch 34/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6431 - loss: 2.7464 - val_accuracy: 0.6340 - val_loss: 0.8971
# Epoch 35/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.6479 - loss: 2.7223 - val_accuracy: 0.6387 - val_loss: 0.8911
# Epoch 36/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6528 - loss: 2.6989 - val_accuracy: 0.6432 - val_loss: 0.8853
# Epoch 37/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6571 - loss: 2.6763 - val_accuracy: 0.6478 - val_loss: 0.8787
# Epoch 38/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6625 - loss: 2.6546 - val_accuracy: 0.6519 - val_loss: 0.8731
# Epoch 39/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6673 - loss: 2.6338 - val_accuracy: 0.6563 - val_loss: 0.8680
# Epoch 40/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6722 - loss: 2.6132 - val_accuracy: 0.6609 - val_loss: 0.8624
# Epoch 41/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.6762 - loss: 2.5936 - val_accuracy: 0.6646 - val_loss: 0.8574
# Epoch 42/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6801 - loss: 2.5746 - val_accuracy: 0.6681 - val_loss: 0.8529
# Epoch 43/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6834 - loss: 2.5562 - val_accuracy: 0.6730 - val_loss: 0.8473
# Epoch 44/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6884 - loss: 2.5385 - val_accuracy: 0.6774 - val_loss: 0.8409
# Epoch 45/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6921 - loss: 2.5213 - val_accuracy: 0.6806 - val_loss: 0.8366
# Epoch 46/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6958 - loss: 2.5045 - val_accuracy: 0.6852 - val_loss: 0.8300
# Epoch 47/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6989 - loss: 2.4883 - val_accuracy: 0.6874 - val_loss: 0.8256
# Epoch 48/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7016 - loss: 2.4728 - val_accuracy: 0.6899 - val_loss: 0.8222
# Epoch 49/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7037 - loss: 2.4579 - val_accuracy: 0.6935 - val_loss: 0.8179
# Epoch 50/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7071 - loss: 2.4434 - val_accuracy: 0.6978 - val_loss: 0.8120
# Epoch 51/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7108 - loss: 2.4295 - val_accuracy: 0.7007 - val_loss: 0.8096
# Epoch 52/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7129 - loss: 2.4159 - val_accuracy: 0.7030 - val_loss: 0.8058
# Epoch 53/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7152 - loss: 2.4028 - val_accuracy: 0.7059 - val_loss: 0.8019
# Epoch 54/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7177 - loss: 2.3901 - val_accuracy: 0.7089 - val_loss: 0.7980
# Epoch 55/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7195 - loss: 2.3780 - val_accuracy: 0.7105 - val_loss: 0.7952
# Epoch 56/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7217 - loss: 2.3662 - val_accuracy: 0.7128 - val_loss: 0.7912
# Epoch 57/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7240 - loss: 2.3547 - val_accuracy: 0.7148 - val_loss: 0.7885
# Epoch 58/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7265 - loss: 2.3436 - val_accuracy: 0.7167 - val_loss: 0.7851
# Epoch 59/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7283 - loss: 2.3326 - val_accuracy: 0.7185 - val_loss: 0.7819
# Epoch 60/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7303 - loss: 2.3219 - val_accuracy: 0.7211 - val_loss: 0.7790
# Epoch 61/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7320 - loss: 2.3117 - val_accuracy: 0.7228 - val_loss: 0.7759
# Epoch 62/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7340 - loss: 2.3018 - val_accuracy: 0.7238 - val_loss: 0.7731
# Epoch 63/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7357 - loss: 2.2922 - val_accuracy: 0.7251 - val_loss: 0.7705
# Epoch 64/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7372 - loss: 2.2828 - val_accuracy: 0.7266 - val_loss: 0.7680
# Epoch 65/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7393 - loss: 2.2735 - val_accuracy: 0.7278 - val_loss: 0.7652
# Epoch 66/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7409 - loss: 2.2646 - val_accuracy: 0.7290 - val_loss: 0.7629
# Epoch 67/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7424 - loss: 2.2560 - val_accuracy: 0.7307 - val_loss: 0.7603
# Epoch 68/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7439 - loss: 2.2476 - val_accuracy: 0.7323 - val_loss: 0.7584
# Epoch 69/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7445 - loss: 2.2392 - val_accuracy: 0.7342 - val_loss: 0.7561
# Epoch 70/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7456 - loss: 2.2311 - val_accuracy: 0.7353 - val_loss: 0.7536
# Epoch 71/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7472 - loss: 2.2229 - val_accuracy: 0.7362 - val_loss: 0.7515
# Epoch 72/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7489 - loss: 2.2151 - val_accuracy: 0.7368 - val_loss: 0.7494
# Epoch 73/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7502 - loss: 2.2076 - val_accuracy: 0.7382 - val_loss: 0.7471
# Epoch 74/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7517 - loss: 2.2001 - val_accuracy: 0.7388 - val_loss: 0.7455
# Epoch 75/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7523 - loss: 2.1931 - val_accuracy: 0.7400 - val_loss: 0.7434
# Epoch 76/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7533 - loss: 2.1863 - val_accuracy: 0.7409 - val_loss: 0.7414
# Epoch 77/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7539 - loss: 2.1797 - val_accuracy: 0.7419 - val_loss: 0.7398
# Epoch 78/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7545 - loss: 2.1733 - val_accuracy: 0.7428 - val_loss: 0.7377
# Epoch 79/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7553 - loss: 2.1671 - val_accuracy: 0.7432 - val_loss: 0.7360
# Epoch 80/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7559 - loss: 2.1611 - val_accuracy: 0.7438 - val_loss: 0.7345
# Epoch 81/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7568 - loss: 2.1554 - val_accuracy: 0.7450 - val_loss: 0.7330
# Epoch 82/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7578 - loss: 2.1497 - val_accuracy: 0.7453 - val_loss: 0.7315
# Epoch 83/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7586 - loss: 2.1441 - val_accuracy: 0.7465 - val_loss: 0.7297
# Epoch 84/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7593 - loss: 2.1386 - val_accuracy: 0.7465 - val_loss: 0.7289
# Epoch 85/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7595 - loss: 2.1335 - val_accuracy: 0.7468 - val_loss: 0.7271
# Epoch 86/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7599 - loss: 2.1282 - val_accuracy: 0.7472 - val_loss: 0.7257
# Epoch 87/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7605 - loss: 2.1232 - val_accuracy: 0.7477 - val_loss: 0.7245
# Epoch 88/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7614 - loss: 2.1182 - val_accuracy: 0.7486 - val_loss: 0.7232
# Epoch 89/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7618 - loss: 2.1134 - val_accuracy: 0.7493 - val_loss: 0.7217
# Epoch 90/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7625 - loss: 2.1086 - val_accuracy: 0.7499 - val_loss: 0.7201
# Epoch 91/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7629 - loss: 2.1040 - val_accuracy: 0.7506 - val_loss: 0.7188
# Epoch 92/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7634 - loss: 2.0994 - val_accuracy: 0.7512 - val_loss: 0.7175
# Epoch 93/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7641 - loss: 2.0951 - val_accuracy: 0.7515 - val_loss: 0.7165
# Epoch 94/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7648 - loss: 2.0907 - val_accuracy: 0.7520 - val_loss: 0.7154
# Epoch 95/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7658 - loss: 2.0864 - val_accuracy: 0.7525 - val_loss: 0.7140
# Epoch 96/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7663 - loss: 2.0822 - val_accuracy: 0.7532 - val_loss: 0.7131
# Epoch 97/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7662 - loss: 2.0780 - val_accuracy: 0.7537 - val_loss: 0.7122
# Epoch 98/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7668 - loss: 2.0740 - val_accuracy: 0.7539 - val_loss: 0.7113
# Epoch 99/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7673 - loss: 2.0701 - val_accuracy: 0.7546 - val_loss: 0.7103
# Epoch 100/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7677 - loss: 2.0662 - val_accuracy: 0.7547 - val_loss: 0.7096
# Epoch 101/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7682 - loss: 2.0625 - val_accuracy: 0.7551 - val_loss: 0.7083
# Epoch 102/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7687 - loss: 2.0588 - val_accuracy: 0.7555 - val_loss: 0.7079
# Epoch 103/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7692 - loss: 2.0551 - val_accuracy: 0.7563 - val_loss: 0.7069
# Epoch 104/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7701 - loss: 2.0515 - val_accuracy: 0.7568 - val_loss: 0.7063
# Epoch 105/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7705 - loss: 2.0480 - val_accuracy: 0.7569 - val_loss: 0.7053
# Epoch 106/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7711 - loss: 2.0443 - val_accuracy: 0.7575 - val_loss: 0.7040
# Epoch 107/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7715 - loss: 2.0410 - val_accuracy: 0.7583 - val_loss: 0.7031
# Epoch 108/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7717 - loss: 2.0375 - val_accuracy: 0.7581 - val_loss: 0.7027
# Epoch 109/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7721 - loss: 2.0343 - val_accuracy: 0.7585 - val_loss: 0.7023
# Epoch 110/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7723 - loss: 2.0313 - val_accuracy: 0.7593 - val_loss: 0.7008
# Epoch 111/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7728 - loss: 2.0278 - val_accuracy: 0.7593 - val_loss: 0.7009
# Epoch 112/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7730 - loss: 2.0247 - val_accuracy: 0.7603 - val_loss: 0.6991
# Epoch 113/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7734 - loss: 2.0215 - val_accuracy: 0.7607 - val_loss: 0.6981
# Epoch 114/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7738 - loss: 2.0186 - val_accuracy: 0.7609 - val_loss: 0.6971
# Epoch 115/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7745 - loss: 2.0154 - val_accuracy: 0.7607 - val_loss: 0.6972
# Epoch 116/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7746 - loss: 2.0127 - val_accuracy: 0.7614 - val_loss: 0.6958
# Epoch 117/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7752 - loss: 2.0098 - val_accuracy: 0.7618 - val_loss: 0.6951
# Epoch 118/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7755 - loss: 2.0068 - val_accuracy: 0.7618 - val_loss: 0.6944
# Epoch 119/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7759 - loss: 2.0039 - val_accuracy: 0.7624 - val_loss: 0.6938
# Epoch 120/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7761 - loss: 2.0011 - val_accuracy: 0.7624 - val_loss: 0.6932
# Epoch 121/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7765 - loss: 1.9983 - val_accuracy: 0.7630 - val_loss: 0.6925
# Epoch 122/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7769 - loss: 1.9955 - val_accuracy: 0.7634 - val_loss: 0.6919
# Epoch 123/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7773 - loss: 1.9929 - val_accuracy: 0.7637 - val_loss: 0.6910
# Epoch 124/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7775 - loss: 1.9902 - val_accuracy: 0.7640 - val_loss: 0.6900
# Epoch 125/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7777 - loss: 1.9875 - val_accuracy: 0.7640 - val_loss: 0.6904
# Epoch 126/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7778 - loss: 1.9850 - val_accuracy: 0.7646 - val_loss: 0.6894
# Epoch 127/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7781 - loss: 1.9825 - val_accuracy: 0.7646 - val_loss: 0.6890
# Epoch 128/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7785 - loss: 1.9800 - val_accuracy: 0.7648 - val_loss: 0.6889
# Epoch 129/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7786 - loss: 1.9775 - val_accuracy: 0.7651 - val_loss: 0.6884
# Epoch 130/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7786 - loss: 1.9750 - val_accuracy: 0.7651 - val_loss: 0.6883
# Epoch 131/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7787 - loss: 1.9727 - val_accuracy: 0.7665 - val_loss: 0.6865
# Epoch 132/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7790 - loss: 1.9704 - val_accuracy: 0.7661 - val_loss: 0.6871
# Epoch 133/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7793 - loss: 1.9679 - val_accuracy: 0.7663 - val_loss: 0.6869
# Epoch 134/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7794 - loss: 1.9657 - val_accuracy: 0.7664 - val_loss: 0.6861
# Epoch 135/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7798 - loss: 1.9633 - val_accuracy: 0.7664 - val_loss: 0.6864
# Epoch 136/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7797 - loss: 1.9613 - val_accuracy: 0.7668 - val_loss: 0.6857
# Epoch 137/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7797 - loss: 1.9589 - val_accuracy: 0.7672 - val_loss: 0.6847
# Epoch 138/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7802 - loss: 1.9567 - val_accuracy: 0.7671 - val_loss: 0.6848
# Epoch 139/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7801 - loss: 1.9547 - val_accuracy: 0.7675 - val_loss: 0.6843
# Epoch 140/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7803 - loss: 1.9524 - val_accuracy: 0.7677 - val_loss: 0.6838
# Epoch 141/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7807 - loss: 1.9505 - val_accuracy: 0.7677 - val_loss: 0.6832
# Epoch 142/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7807 - loss: 1.9482 - val_accuracy: 0.7685 - val_loss: 0.6817
# Epoch 143/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7813 - loss: 1.9461 - val_accuracy: 0.7686 - val_loss: 0.6820
# Epoch 144/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7814 - loss: 1.9441 - val_accuracy: 0.7689 - val_loss: 0.6812
# Epoch 145/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7819 - loss: 1.9422 - val_accuracy: 0.7694 - val_loss: 0.6806
# Epoch 146/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7820 - loss: 1.9401 - val_accuracy: 0.7695 - val_loss: 0.6802
# Epoch 147/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7823 - loss: 1.9382 - val_accuracy: 0.7703 - val_loss: 0.6791
# Epoch 148/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7825 - loss: 1.9362 - val_accuracy: 0.7699 - val_loss: 0.6793
# Epoch 149/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7825 - loss: 1.9341 - val_accuracy: 0.7709 - val_loss: 0.6782
# Epoch 150/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7826 - loss: 1.9323 - val_accuracy: 0.7706 - val_loss: 0.6786

# %%
# Training Loss plot
loss_values = history.history['loss']
epochs = range(1, len(loss_values)+1)

plt.plot(epochs, loss_values, label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
#plt.ylim(0, 10)
plt.legend()

plt.show()

# %%
# Prediction confusion matrix
y_prediction = model.predict(x_test)
y_prediction = np.argmax(y_prediction, axis = 1)
y_test_pred = np.argmax(y_test, axis=1)


# Create confusion matrix and normalize it over predicted (columns)
#result = confusion_matrix(y_test_pred, y_prediction , normalize='pred')
result = confusion_matrix(y_test_pred, y_prediction , normalize='true')
#result = confusion_matrix(y_test_pred, y_prediction , normalize='all')
#result = confusion_matrix(y_test_pred, y_prediction)
classes = [0,1,2,3,4]
result_norm = np.around(result, 3)
#result_norm = result
mat_result = pd.DataFrame(result_norm,
                     index = classes, 
                     columns = classes)

total_pred = np.trace(result) / 5

print('Confusion matrix')
print(mat_result)
print()
print('Average accuracy')
print(total_pred)
# Out:
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 1s 964us/step
# Confusion matrix
#        0      1      2      3      4
# 0  0.752  0.138  0.026  0.064  0.020
# 1  0.144  0.784  0.023  0.019  0.031
# 2  0.038  0.044  0.823  0.061  0.034
# 3  0.076  0.017  0.110  0.797  0.000
# 4  0.041  0.011  0.017  0.014  0.918
#
# Average accuracy
# 0.8144727158547761

# %%
# Print detailed results
target_names = ['class 0', 'class 1', 'class 2', 'class 3', 'class 4']
print(classification_report(y_test_pred, y_prediction, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.98      0.75      0.85     14483
#      class 1       0.16      0.78      0.26       485
#      class 2       0.68      0.82      0.74      1093
#      class 3       0.08      0.80      0.15       118
#      class 4       0.78      0.92      0.84      1322
#
#     accuracy                           0.77     17501
#    macro avg       0.54      0.81      0.57     17501
# weighted avg       0.92      0.77      0.82     17501

# %%
model_num = 0
#while os.path.exists(MODEL_PATH_BASE + MODEL_NAME_BASE + "%s.keras" % f"{model_num:02}"):
#    model_num += 1
log_dir = LOG_DIR
#model_name = MODEL_NAME_BASE+ str(f"{model_num:02}")
model_name = MODEL_NAME_BASE+ str(f"{NEURONS:02}")
model_path = MODEL_PATH_BASE + model_name + '.keras'
model.name = model_name
#model.save(model_path)

# %%
model_name = "mlp_beat"+str(f"{HEARTBEAT_LENGTH:03}")+"_rand"+str(f"{POINTS_LENGTH:03}")+"_n"+str(f"{NEURONS:02}")

# %%
figure = plt.figure(figsize=(4, 4))
sns.heatmap(mat_result, annot=True,cmap=plt.cm.Blues)
plt.title(model_name)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.tight_layout()
#plt.savefig(log_dir + '/' + model_name + '.png', pad_inches=0.1)
plt.show()
