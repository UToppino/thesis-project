# %% [markdown]
# ## MLP + peak/valley classification
# Extract heartbeats from raw dataset and trains an MLP for classification:
# - Extract all usable heartbeats of fixed length from the raw data
# - Uses the peak/valley algorithm to extract N peak amplitudes
# - Trains an MLP network on the selected peaks

# %%
# Importing packages
import copy
import datetime
import numpy as np
import pandas as pd
import random
import seaborn as sns
import matplotlib.pyplot as plt
import math
from scipy import signal
import keras
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
import keras
import keras_tuner as kt
from keras.utils import to_categorical
from keras.layers import Dense, Convolution1D, Convolution2D, MaxPool1D, Flatten, Dropout, AveragePooling1D
from keras.layers import Input
from keras import initializers
from keras.models import Model, Sequential
from keras.layers import BatchNormalization
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.utils import class_weight
from sklearn.utils import resample
import warnings
import wfdb
import os
import tensorflow as tf
warnings.filterwarnings('ignore')

# %%
### PARAMETERS TO SET ###

# Balance the weight of the different classes of the (unbalanced) dataset
CUSTOM_WEIGHTS = True

# Parameters for heartbeat extraction
# Number of samples to consider as the length of an heartbeat
HEARTBEAT_LENGTH = 400
# Number of random points to extract from heartbeat
POINTS_LENGTH = 32

# Parameters for float to integer conversion
# 16bits max and min values
INT_RANGE = 65536
INT_LOW = -32768
INT_HIGH = 32767
# Wether to convert down to 8bit or stay at 16bit
CONV_8BIT = True
print("Range: "+str(INT_RANGE)+"   MIN: "+str(INT_LOW)+"   MAX:"+str(INT_HIGH))

# Parameters for saving files
# Confusion matrix img is saved in LOG_DIR
# Model is stored in MODEL_PATH_BASE with name MODEL_NAME_BASE plus two digits
LOG_DIR = "logs/mlp_only/"
MODEL_NAME_BASE = 'mlp_only_'
MODEL_PATH_BASE = 'models/mlp_only/'
# Out:
# Range: 65536   MIN: -32768   MAX:32767

# %%
# Parameters for determinism
KERAS_SEED = 1234509876
keras.utils.set_random_seed(KERAS_SEED)
tf.config.experimental.enable_op_determinism()

# %%
### Extract data from files
mitdb_list = [100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 111, 112, 113, 114, 115, 116, 117, 118, 119, 121, 122, 123, 124, 200, 201, 202, 203, 205, 207, 208, 209, 210, 212, 213, 214, 215, 217, 219, 220, 221, 222, 223, 228, 230, 231, 232, 233, 234]

if CONV_8BIT:
    v_dataset_data = np.empty((1,HEARTBEAT_LENGTH), dtype=np.int8)
else:
    v_dataset_data = np.empty((1,HEARTBEAT_LENGTH), dtype=np.int16)

# Float dataset
v_dataset_data = np.empty((1,HEARTBEAT_LENGTH), dtype=float)
v_dataset_categ = np.empty(1, dtype=str)

v_data_min = 10.0
v_data_max = -10.0

for element in mitdb_list:
    record = wfdb.rdrecord('../src/mitdb/' + str(element))
    v_data_min = np.min(record.p_signal) if np.min(record.p_signal) < v_data_min else v_data_min
    v_data_max = np.max(record.p_signal) if np.max(record.p_signal) > v_data_max else v_data_max

v_data_abs_max = np.max(np.abs([v_data_min, v_data_max]))

print("MAX: " + str(v_data_max) + "   MIN: " + str(v_data_min))
print("ABS MAX: " +str(v_data_abs_max))

for element in mitdb_list:


    print("##########")
    print("Current record: " + str(element))

    # Load all samples
    record = wfdb.rdrecord('src/mitdb/' + str(element))
    annotation = wfdb.rdann('src/mitdb/'+str(element), 'atr')

    # Convert annotations to useful ones
    # Read symbols and substitute them
    # Classes:  'N': Normal beat
    #           'S': Supraventricular premature
    #           'V': Premature ventricular contraction
    #           'F': Fusion of ventricular and normal beat
    #           'Q': Unclassifiable
    #
    # CLASSIFICATION
    # Based on the paper "A deep convolutional neural network model to classify heartbeats"
    symbol_dict = { 'N':'N', 'L':'N', 'R':'N', 'e':'N', 'j':'N',
                    'S':'S', 'A':'S', 'a':'S', 'J':'S',
                    'V':'V', 'E':'V',
                    'F':'F',
                    'Q':'Q', '/':'Q', 'f':'Q'}
    raw_ann_symbol = annotation.symbol.copy()
    raw_ann_sample = annotation.sample.copy()
    #raw_ann_symbol = [symbol_dict[key] if key in symbol_dict else key for key in raw_ann_symbol]
    raw_ann_symbol = [symbol_dict[key] if key in symbol_dict else 'Z' for key in raw_ann_symbol]

    # Delete non beat annotations
    if 'Z' in raw_ann_symbol:
        i_del = [i for i, x in enumerate(raw_ann_symbol) if x == 'Z']
        raw_ann_sample = np.delete(raw_ann_sample, i_del)
        raw_ann_symbol = np.delete(raw_ann_symbol, i_del)

    # Extract ECG data array
    v_data_f = record.p_signal
    v_data_f = v_data_f[:,0]

    # Convert data from float to uint16
    #v_data = np.zeros_like(v_data_f, dtype=np.int16)
    #for i in range(0, len(v_data_f)):
    #    # Offset and scale
    #    #v_data[i] = ((v_data_f[i]-v_data_min)/(v_data_max - v_data_min))*(INT_RANGE)+(INT_LOW)
    #    # Scale only
    #    v_data[i] = np.int16((v_data_f[i])/(v_data_abs_max)*(INT_HIGH))
    #    if CONV_8BIT:
    #        v_data[i] = np.int8((v_data[i] >> 8) & 0xFF)

    # If using float instead of int
    #v_data = v_data_f/v_data_abs_max*INT_HIGH
    v_data = v_data_f

    print(v_data_f)
    print(v_data)

    # Define time array (Fs:360Hz)
    v_time = np.arange(0, HEARTBEAT_LENGTH, 1, dtype=int)

    # Zeros array for x-axis
    axis_x = np.zeros_like(v_time)

    # Delete annotations for beats too close to the beginning or ending of signal
    raw_ann_symbol = raw_ann_symbol[(raw_ann_sample > (HEARTBEAT_LENGTH/2+1)) & (raw_ann_sample < (len(v_data)-(HEARTBEAT_LENGTH/2+1)))]
    raw_ann_sample = raw_ann_sample[(raw_ann_sample > (HEARTBEAT_LENGTH/2+1)) & (raw_ann_sample < (len(v_data)-(HEARTBEAT_LENGTH/2+1)))]

    print(raw_ann_symbol)
    print(raw_ann_sample)
    print(len(raw_ann_symbol))
    print(len(raw_ann_sample))
    
    # Divide signal in single heartbeats
    v_total_data = np.zeros(shape=(len(raw_ann_symbol),HEARTBEAT_LENGTH))
    v_total_categ = np.empty(len(raw_ann_symbol), dtype=str)
    for i in range(0, len(v_total_data)-1):
        v_total_data[i,:] = v_data[(raw_ann_sample[i] - int(HEARTBEAT_LENGTH/2)) : (raw_ann_sample[i] + int(HEARTBEAT_LENGTH/2))]
        v_total_categ[i] = raw_ann_symbol[i]
        #print(v_total_data[i,:])

    # Delete empty data
    v_total_data = v_total_data[v_total_categ != '']
    v_total_categ = v_total_categ[v_total_categ != '']

    # Copy results to dataset variables
    v_dataset_data = np.append(v_dataset_data, v_total_data, axis=0)
    v_dataset_categ = np.append(v_dataset_categ, v_total_categ)

# Delete first element (empty)
v_dataset_data = v_dataset_data[1:,:]
v_dataset_categ = v_dataset_categ[1:]

print(v_dataset_categ)
print(v_dataset_data)
# Out:
# MAX: 5.115   MIN: -5.12
# ABS MAX: 5.12
# ##########
# Current record: 100
# [-0.145 -0.145 -0.145 ... -0.675 -0.765 -1.28 ]
# [-0.145 -0.145 -0.145 ... -0.675 -0.765 -1.28 ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   370    662    946 ... 649232 649484 649734]
# 2271
# 2271
# ##########
# Current record: 101
# [-0.345 -0.345 -0.345 ... -0.295 -0.29   0.   ]
# [-0.345 -0.345 -0.345 ... -0.295 -0.29   0.   ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   396    711   1032 ... 649004 649372 649751]
# 1864
# 1864
# ##########
# Current record: 102
# [-0.2   -0.2   -0.2   ... -0.17  -0.195  0.   ]
# [-0.2   -0.2   -0.2   ... -0.17  -0.195  0.   ]
# ['Q' 'Q' 'Q' ... 'Q' 'Q' 'Q']
# [   410    697    989 ... 648931 649244 649553]
# 2185
# 2185
# ##########
# Current record: 103
# [-0.375 -0.375 -0.375 ... -0.235 -0.245  0.   ]
# [-0.375 -0.375 -0.375 ... -0.235 -0.245  0.   ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   265    575    876 ... 648872 649195 649534]
# 2083
# 2083
# ##########
# Current record: 104
# [-0.15  -0.15  -0.15  ... -0.065 -0.06   0.   ]
# [-0.15  -0.15  -0.15  ... -0.065 -0.06   0.   ]
# ['Q' 'Q' 'Q' ... 'Q' 'Q' 'Q']
# [   316    615    901 ... 649022 649300 649580]
# 2227
# 2227
# ##########
# Current record: 105
# [-0.445 -0.445 -0.445 ...  0.59   0.76   1.28 ]
# [-0.445 -0.445 -0.445 ...  0.59   0.76   1.28 ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   459    708    965 ... 649221 649471 649740]
# 2571
# 2571
# ##########
# Current record: 106
# [-0.31  -0.31  -0.31  ...  0.635  0.265  0.   ]
# [-0.31  -0.31  -0.31  ...  0.635  0.265  0.   ]
# ['N' 'N' 'N' ... 'V' 'V' 'N']
# [   351    724   1086 ... 649162 649340 649791]
# 2027
# 2027
# ##########
# Current record: 107
# [-2.045 -2.045 -2.045 ... -0.645 -0.635  0.   ]
# [-2.045 -2.045 -2.045 ... -0.645 -0.635  0.   ]
# ['Q' 'Q' 'Q' ... 'Q' 'Q' 'Q']
# [   272    569    884 ... 649129 649441 649748]
# 2136
# 2136
# ##########
# Current record: 108
# [-0.125 -0.125 -0.125 ... -0.01   0.04   0.   ]
# [-0.125 -0.125 -0.125 ... -0.01   0.04   0.   ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   442    789   1155 ... 649170 649471 649769]
# 1762
# 1762
# ##########
# Current record: 109
# [ 0.175  0.175  0.175 ... -0.92  -0.91  -1.28 ]
# [ 0.175  0.175  0.175 ... -0.92  -0.91  -1.28 ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   343    571    807 ... 649109 649378 649663]
# 2530
# 2530
# ##########
# Current record: 111
# [-0.035 -0.035 -0.035 ...  0.155  0.2    0.   ]
# [-0.035 -0.035 -0.035 ...  0.155  0.2    0.   ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   489    804   1127 ... 649148 649441 649724]
# 2123
# 2123
# ##########
# Current record: 112
# [-0.75  -0.75  -0.75  ... -0.825 -0.81  -1.28 ]
# [-0.75  -0.75  -0.75  ... -0.825 -0.81  -1.28 ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   382    644    892 ... 649105 649361 649626]
# 2537
# 2537
# ##########
# Current record: 113
# [-0.46 -0.46 -0.46 ...  1.06  0.42  0.  ]
# [-0.46 -0.46 -0.46 ...  1.06  0.42  0.  ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   583    966   1326 ... 649008 649364 649675]
# 1793
# 1793
# ##########
# Current record: 114
# [-0.045 -0.045 -0.045 ... -0.365 -0.37   0.   ]
# [-0.045 -0.045 -0.045 ... -0.365 -0.37   0.   ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   310    726   1143 ... 649261 649523 649783]
# 1879
# 1879
# ##########
# Current record: 115
# [-0.58 -0.58 -0.58 ... -0.75 -0.75 -1.28]
# [-0.58 -0.58 -0.58 ... -0.75 -0.75 -1.28]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   518    850   1211 ... 649055 649357 649647]
# 1951
# 1951
# ##########
# Current record: 116
# [-0.32  -0.32  -0.32  ... -0.975 -0.96  -1.28 ]
# [-0.32  -0.32  -0.32  ... -0.975 -0.96  -1.28 ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   282    561    837 ... 649191 649442 649701]
# 2411
# 2411
# ##########
# Current record: 117
# [-0.925 -0.925 -0.925 ... -0.585 -0.565  0.   ]
# [-0.925 -0.925 -0.925 ... -0.585 -0.565  0.   ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   598   1006   1408 ... 648653 649070 649498]
# 1533
# 1533
# ##########
# Current record: 118
# [-0.835 -0.835 -0.835 ...  0.03   0.085  0.   ]
# [-0.835 -0.835 -0.835 ...  0.03   0.085  0.   ]
# ['N' 'N' 'N' ... 'N' 'S' 'N']
# [   369    674    980 ... 649226 649429 649742]
# 2277
# 2277
# ##########
# Current record: 119
# [-0.995 -0.995 -0.995 ...  1.565  1.525  1.28 ]
# [-0.995 -0.995 -0.995 ...  1.565  1.525  1.28 ]
# ['N' 'V' 'N' ... 'N' 'N' 'N']
# [   309    503    977 ... 649129 649468 649788]
# 1987
# 1987
# ##########
# Current record: 121
# [-0.875 -0.875 -0.875 ... -0.86  -0.875 -1.28 ]
# [-0.875 -0.875 -0.875 ... -0.86  -0.875 -1.28 ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   513    874   1217 ... 648996 649287 649587]
# 1861
# 1861
# ##########
# Current record: 122
# [-0.78 -0.78 -0.78 ... -1.02 -1.04 -1.28]
# [-0.78 -0.78 -0.78 ... -1.02 -1.04 -1.28]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   326    561    798 ... 649126 649383 649643]
# 2474
# 2474
# ##########
# Current record: 123
# [-0.805 -0.805 -0.805 ... -1.25  -1.225 -1.28 ]
# [-0.805 -0.805 -0.805 ... -1.25  -1.225 -1.28 ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   550   1021   1498 ... 648997 649342 649689]
# 1517
# 1517
# ##########
# Current record: 124
# [-1.    -1.    -1.    ... -0.72  -0.705 -1.28 ]
# [-1.    -1.    -1.    ... -0.72  -0.705 -1.28 ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   243    693   1119 ... 648786 649146 649510]
# 1618
# 1618
# ##########
# Current record: 200
# [0.35  0.35  0.35  ... 0.015 0.015 0.   ]
# [0.35  0.35  0.35  ... 0.015 0.015 0.   ]
# ['V' 'N' 'V' ... 'N' 'N' 'N']
# [   225    487    689 ... 649161 649408 649664]
# 2600
# 2600
# ##########
# Current record: 201
# [-0.26 -0.26 -0.26 ... -0.17 -0.18  0.  ]
# [-0.26 -0.26 -0.26 ... -0.17 -0.18  0.  ]
# ['N' 'N' 'N' ... 'N' 'S' 'N']
# [   415    686    905 ... 648419 648594 649104]
# 1961
# 1961
# ##########
# Current record: 202
# [ 0.    0.    0.   ... -0.24 -0.24  0.  ]
# [ 0.    0.    0.   ... -0.24 -0.24  0.  ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   348    742   1155 ... 649092 649342 649615]
# 2135
# 2135
# ##########
# Current record: 203
# [-0.26 -0.26 -0.26 ... -0.55 -0.52  0.  ]
# [-0.26 -0.26 -0.26 ... -0.55 -0.52  0.  ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   431    660    862 ... 649237 649448 649777]
# 2979
# 2979
# ##########
# Current record: 205
# [-0.43  -0.43  -0.43  ... -0.365 -0.375  0.   ]
# [-0.43  -0.43  -0.43  ... -0.365 -0.375  0.   ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   229    466    706 ... 649060 649326 649596]
# 2655
# 2655
# ##########
# Current record: 207
# [-0.215 -0.215 -0.215 ... -1.19  -1.135 -1.28 ]
# [-0.215 -0.215 -0.215 ... -1.19  -1.135 -1.28 ]
# ['V' 'N' 'V' ... 'S' 'S' 'S']
# [   312    835   1078 ... 649262 649431 649602]
# 1858
# 1858
# ##########
# Current record: 208
# [-0.105 -0.105 -0.105 ... -0.17  -0.16   0.   ]
# [-0.105 -0.105 -0.105 ... -0.17  -0.16   0.   ]
# ['V' 'N' 'F' ... 'N' 'V' 'N']
# [   209    483    697 ... 649206 649411 649704]
# 2953
# 2953
# ##########
# Current record: 209
# [-0.02  -0.02  -0.02  ... -0.265 -0.28   0.   ]
# [-0.02  -0.02  -0.02  ... -0.265 -0.28   0.   ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   425    659    889 ... 649149 649387 649627]
# 3003
# 3003
# ##########
# Current record: 210
# [-0.065 -0.065 -0.065 ... -0.305 -0.3    0.   ]
# [-0.065 -0.065 -0.065 ... -0.305 -0.3    0.   ]
# ['N' 'N' 'V' ... 'N' 'V' 'N']
# [   250    471    625 ... 649216 649513 649758]
# 2648
# 2648
# ##########
# Current record: 212
# [-0.5  -0.5  -0.5  ... -0.34 -0.33  0.  ]
# [-0.5  -0.5  -0.5  ... -0.34 -0.33  0.  ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   214    451    696 ... 649141 649414 649673]
# 2747
# 2747
# ##########
# Current record: 213
# [-0.01  -0.01  -0.01  ...  1.135  0.715  1.28 ]
# [-0.01  -0.01  -0.01  ...  1.135  0.715  1.28 ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   253    478    673 ... 649374 649577 649790]
# 3249
# 3249
# ##########
# Current record: 214
# [-0.095 -0.095 -0.095 ... -0.32  -0.285  0.   ]
# [-0.095 -0.095 -0.095 ... -0.32  -0.285  0.   ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   346    660    975 ... 649112 649379 649627]
# 2260
# 2260
# ##########
# Current record: 215
# [ 0.22   0.22   0.22  ... -0.285 -0.28   0.   ]
# [ 0.22   0.22   0.22  ... -0.285 -0.28   0.   ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   313    503    704 ... 649304 649501 649685]
# 3361
# 3361
# ##########
# Current record: 217
# [ 0.045  0.045  0.045 ... -0.36  -0.33   0.   ]
# [ 0.045  0.045  0.045 ... -0.36  -0.33   0.   ]
# ['Q' 'Q' 'Q' ... 'Q' 'Q' 'Q']
# [   205    500    812 ... 649114 649429 649738]
# 2208
# 2208
# ##########
# Current record: 219
# [-0.695 -0.695 -0.695 ... -0.89  -0.885 -1.28 ]
# [-0.695 -0.695 -0.695 ... -0.89  -0.885 -1.28 ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   300    614    887 ... 649174 649448 649737]
# 2154
# 2154
# ##########
# Current record: 220
# [-0.69  -0.69  -0.69  ... -0.16  -0.155  0.   ]
# [-0.69  -0.69  -0.69  ... -0.16  -0.155  0.   ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   313    612    916 ... 648966 649277 649584]
# 2046
# 2046
# ##########
# Current record: 221
# [-0.285 -0.285 -0.285 ... -0.235 -0.245  0.   ]
# [-0.285 -0.285 -0.285 ... -0.235 -0.245  0.   ]
# ['N' 'N' 'V' ... 'N' 'N' 'N']
# [   220    442    603 ... 648982 649236 649530]
# 2426
# 2426
# ##########
# Current record: 222
# [-0.14 -0.14 -0.14 ... -0.27 -0.28  0.  ]
# [-0.14 -0.14 -0.14 ... -0.27 -0.28  0.  ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   361    646    892 ... 649157 649317 649600]
# 2481
# 2481
# ##########
# Current record: 223
# [-0.93  -0.93  -0.93  ... -0.55  -0.555  0.   ]
# [-0.93  -0.93  -0.93  ... -0.55  -0.555  0.   ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   204    480    759 ... 649091 649349 649599]
# 2604
# 2604
# ##########
# Current record: 228
# [-0.155 -0.155 -0.155 ... -0.29  -0.285  0.   ]
# [-0.155 -0.155 -0.155 ... -0.29  -0.285  0.   ]
# ['N' 'N' 'N' ... 'N' 'V' 'N']
# [   433    726   1061 ... 649108 649332 649761]
# 2052
# 2052
# ##########
# Current record: 230
# [-0.38 -0.38 -0.38 ... -0.59 -0.59  0.  ]
# [-0.38 -0.38 -0.38 ... -0.59 -0.59  0.  ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   349    616    880 ... 649106 649338 649572]
# 2254
# 2254
# ##########
# Current record: 231
# [-0.2  -0.2  -0.2  ...  0.34  0.34  0.  ]
# [-0.2  -0.2  -0.2  ...  0.34  0.34  0.  ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   527    847   1166 ... 648811 649142 649501]
# 1569
# 1569
# ##########
# Current record: 232
# [-0.245 -0.245 -0.245 ... -0.07  -0.075  0.   ]
# [-0.245 -0.245 -0.245 ... -0.07  -0.075  0.   ]
# ['N' 'S' 'S' ... 'N' 'S' 'S']
# [   491    737   1000 ... 648845 649097 649366]
# 1780
# 1780
# ##########
# Current record: 233
# [-0.095 -0.095 -0.095 ... -0.495 -0.49   0.   ]
# [-0.095 -0.095 -0.095 ... -0.495 -0.49   0.   ]
# ['N' 'V' 'N' ... 'V' 'N' 'N']
# [   320    511    749 ... 649237 649518 649730]
# 3077
# 3077
# ##########
# Current record: 234
# [-0.08  -0.08  -0.08  ... -0.395 -0.38   0.   ]
# [-0.08  -0.08  -0.08  ... -0.395 -0.38   0.   ]
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [   366    606    841 ... 649292 649536 649772]
# 2752
# 2752
# ['N' 'N' 'N' ... 'N' 'N' 'N']
# [[-0.365 -0.36  -0.37  ... -0.335 -0.345 -0.35 ]
#  [-0.45  -0.435 -0.445 ... -0.36  -0.355 -0.36 ]
#  [-0.41  -0.415 -0.42  ... -0.35  -0.355 -0.345]
#  ...
#  [-0.35  -0.335 -0.325 ... -0.17  -0.17  -0.155]
#  [-0.34  -0.345 -0.35  ... -0.055 -0.07  -0.065]
#  [-0.385 -0.39  -0.395 ... -0.065 -0.06  -0.055]]

# %%
# Conversion of float to an 8bit-equivalent precision
v_dataset_data_conv = np.zeros_like(v_dataset_data, dtype=float)
v_dataset_data_8bit = np.zeros_like(v_dataset_data, dtype=np.int8)
v_dataset_data_16bit = np.zeros_like(v_dataset_data, dtype=np.int16)
for i in range(0, len(v_dataset_data_conv)):
    for j in range(0, len(v_dataset_data_conv[i])):
        # Conversion to 16bit
        v_dataset_data_16bit[i][j] = np.int16(v_dataset_data[i][j]/(v_data_abs_max)*(INT_HIGH))
        # Truncation to 8 MSB (8 bit precision)
        v_dataset_data_16bit[i][j] = (v_dataset_data_16bit[i][j] & 0xFF00)
        # Float with 8bit-equivalent precision
        v_dataset_data_conv[i][j] = float(v_dataset_data_16bit[i][j])
        v_dataset_data_conv[i][j] = v_dataset_data_conv[i][j]/(INT_HIGH)*(v_data_abs_max)

v_dataset_data = v_dataset_data_conv

# %%
#print(v_dataset_data_conv)

# %%
# Extract N random numbers from heartbeat
random_indices = np.random.choice(HEARTBEAT_LENGTH, size=POINTS_LENGTH, replace=False)
random_indices = np.sort(random_indices)
v_dataset_data_rand = [arr[random_indices] for arr in v_dataset_data]
#print(v_dataset_data)
#print(random_indices)

# %%
# Apply peak/valley algorith to all heartbeats
# Identify potential peaks
# Compare 3 signal samples S0, S1, S2
# Peak if:  S1>=S0 and S1>S2
#           S1<=S0 and S1<S2

FREQ_SAMPLE = 360

DELTA_PEAK = 0.1
#DELTA_TIME = 75/FREQ_SAMPLE     # Number of samples / Sampling frequency
DELTA_TIME = 15

v_peaks_data = np.zeros_like(v_dataset_data)
v_peaks_time = np.zeros_like(v_dataset_data, dtype=int)

print(v_peaks_data.shape)

for n in range(len(v_dataset_data)):
    j = 0
    # Walk through all samples
    for i in range(1, len(v_dataset_data[n])-1):
        # Identify peak
        if  ((v_dataset_data[n][i] >= v_dataset_data[n][i-1]) and (v_dataset_data[n][i] > v_dataset_data[n][i+1])) or \
            ((v_dataset_data[n][i] <= v_dataset_data[n][i-1]) and (v_dataset_data[n][i] < v_dataset_data[n][i+1])):
            # Check if peak value big enough
            if  (abs(v_dataset_data[n][i] - v_peaks_data[n][j-1]) > DELTA_PEAK) or \
                (abs(v_time[i] - v_peaks_time[n][j-1]) > DELTA_TIME):
                v_peaks_data[n][j] = v_dataset_data[n][i]
                v_peaks_time[n][j] = v_time[i]
                j += 1
                

    #v_peaks_data = v_peaks_data[v_peaks_time != 0]
    #v_peaks_time = v_peaks_time[v_peaks_time != 0]
# Out:
# (109381, 400)

# %%
# Select useful peaks and valleys for training

low_time = np.zeros(shape=int(POINTS_LENGTH/2), dtype=int)
high_time = np.zeros(shape=int(POINTS_LENGTH/2), dtype=int)
points_time = np.zeros(shape=(len(v_peaks_time), POINTS_LENGTH), dtype=int)
points_data = np.zeros(shape=(len(v_peaks_time), POINTS_LENGTH))

for n in range(len(v_peaks_time)):
    #print("n: "+str(n))
    # Split array in half
    low_time_tmp = v_peaks_time[n][v_peaks_time[n] <= int(HEARTBEAT_LENGTH/2)]
    high_time_tmp = v_peaks_time[n][v_peaks_time[n] > int(HEARTBEAT_LENGTH/2)]

    low_time_tmp = low_time_tmp[low_time_tmp != 0]
    high_time_tmp = high_time_tmp[high_time_tmp != 0]
    #print("low_time_tmp1: "+str(low_time_tmp))

    # Select correct number of points from each half
    low_time_tmp = low_time_tmp[-int(POINTS_LENGTH/2):]
    high_time_tmp = high_time_tmp[:int(POINTS_LENGTH/2)]
    #print("low_time_tmp2: "+str(low_time_tmp))

    # Check if the correct number of points were selected
    if len(low_time_tmp) > 0:
        low_time[-len(low_time_tmp):] = low_time_tmp
    else:
        low_time = np.zeros(shape=int(POINTS_LENGTH/2), dtype=int)
    if len(high_time_tmp) > 0:
        high_time[:len(high_time_tmp):] = high_time_tmp
    else:
        high_time = np.zeros(shape=int(POINTS_LENGTH/2), dtype=int)

    # Copy points to final arrays
    points_time[n] = np.append(low_time, high_time)
    points_data[n] = v_dataset_data[n][points_time[n]]

    
    #print("points_time[n]: "+str(points_time[n]))
    #print("points_data[n]: "+str(points_data[n]))

# %%
# Turn absolute aplitudes to deltas
print(points_data[1])

for n in range(len(points_data)):
    points_data_tmp = np.zeros_like(points_data[n])
    points_data_tmp = np.copy(points_data[n])
    for i in range(1, len(points_data_tmp)):
        points_data_tmp[i] = points_data[n][i] - points_data[n][i-1]
    points_data[n] = points_data_tmp

print(points_data[1])
# Out:
# [-0.48001465 -0.48001465 -0.48001465 -0.48001465 -0.44001343 -0.44001343
#  -0.32000977 -0.32000977 -0.32000977 -0.36001099 -0.36001099 -0.24000732
#  -0.28000855 -0.40001221 -0.40001221 -0.52001587  0.92002808 -0.52001587
#  -0.40001221 -0.44001343 -0.44001343 -0.44001343 -0.32000977 -0.36001099
#  -0.40001221 -0.36001099 -0.40001221 -0.48001465 -0.48001465 -0.48001465
#  -0.48001465 -0.48001465]
# [-0.48001465  0.          0.          0.          0.04000122  0.
#   0.12000366  0.          0.         -0.04000122  0.          0.12000366
#  -0.04000122 -0.12000366  0.         -0.12000366  1.44004395 -1.44004395
#   0.12000366 -0.04000122  0.          0.          0.12000366 -0.04000122
#  -0.04000122  0.04000122 -0.04000122 -0.08000244  0.          0.
#   0.          0.        ]

# %%
# Backup dataset to other variable

### All points
#v_dataset_data_bk = np.copy(v_dataset_data)
### Random selection of points
#v_dataset_data_bk = np.copy(v_dataset_data_rand)
### Peak/valley
v_dataset_data_bk = np.copy(points_data)


v_dataset_categ_bk = np.copy(v_dataset_categ)

# %%
# Plotting window
X_MIN = 0
X_MAX = 400
N_ROW = 5
N_COL = 1
PLOT_LOW = INT_LOW
PLOT_HIGH = INT_HIGH

if CONV_8BIT:
    PLOT_LOW = -128
    PLOT_HIGH = 127

n = 0
# Create plots
fig, axs = plt.subplots(N_ROW, N_COL, sharex=True)
fig.set_size_inches(15, 3*N_ROW)
fig.suptitle("ECG Signal conditioning")
axs[n].set_xlim(X_MIN, X_MAX)

for n in range(0, N_ROW):
    # First plot
    rand = random.randint(0, points_time.shape[0])
    axs[n].title.set_text('Plot')
    axs[n].plot(v_dataset_data[rand], 'b', label="raw data", linewidth=0.5)
    axs[n].plot(points_time[rand], points_data[rand], 'r.', label="raw data", linewidth=0.5)
    #n += 1



# First plot
#axs[n].title.set_text('Plot')
#axs[n].plot(v_time, axis_x, linewidth=0.2, color="black")
#axs[n].plot(v_time, v_dataset_data[n], 'b', label="raw data", linewidth=0.5)
#axs[n].legend()
#n += 1

# First plot
#axs[n].title.set_text('Plot')
#axs[n].plot(v_time, axis_x, linewidth=0.2, color="black")
#axs[n].plot(v_time, v_data, 'b', label="raw data", linewidth=0.5)
#axs[n].plot(v_peaks_R_time, v_peaks_R_data, 'mo', label="R peaks", linewidth=0.5)
#axs[n].plot(v_peaks_P_time, v_peaks_P_data, 'bo', label="P peaks", linewidth=0.5)
#axs[n].plot(v_peaks_T_time, v_peaks_T_data, 'ro', label="T peaks", linewidth=0.5)
#axs[n].legend()
#n += 1

plt.tight_layout()
plt.show()

# %%
#stop

# %%
# Copy from backup data
dataset_categ = np.copy(v_dataset_categ_bk)
dataset_data = np.copy(v_dataset_data_bk)

# Convert symbols to numbers
category_dict = {   'N':0,
                    'S':1,
                    'V':2,
                    'F':3,
                    'Q':4}
dataset_categ = [category_dict[key] if key in category_dict else 'Z' for key in dataset_categ]

# Divide data into sets
DATA_SPLIT = 0.2
SEED = 1029384756
set_train, x_valid, target_train, y_valid = train_test_split(dataset_data, dataset_categ, test_size=DATA_SPLIT, random_state=SEED)
x_train, x_test, y_train, y_test = train_test_split(set_train, target_train, test_size=DATA_SPLIT, random_state=SEED)

y_train=to_categorical(y_train)
y_test=to_categorical(y_test)
y_valid=to_categorical(y_valid)

# %%
# Calculate cutom weights for training
tot_y_train = np.sum(y_train, axis=0)
tot_y_test = np.sum(y_test, axis=0)
tot_y_valid = np.sum(y_valid, axis=0)
tot_y_all = tot_y_train + tot_y_test + tot_y_valid

print(tot_y_train)
print(tot_y_test)
print(tot_y_valid)
print(tot_y_all)

max_class = np.max(tot_y_train)
#max_class = np.sum(tot_y_train)

custom_weights = {  0: int(max_class/tot_y_train[0]),
                    1: int(max_class/tot_y_train[1]),
                    2: int(max_class/tot_y_train[2]),
                    3: int(max_class/tot_y_train[3]),
                    4: int(max_class/tot_y_train[4])}

print(custom_weights)
# Out:
# [57974.  1776.  4643.   520.  5090.]
# [14483.   485.  1093.   118.  1322.]
# [18075.   517.  1499.   164.  1622.]
# [90532.  2778.  7235.   802.  8034.]
# {0: 1, 1: 32, 2: 12, 3: 111, 4: 11}

# %%
# Define NN structure
NEURONS = 20
LEARNING_RATE = 0.0001
model = Sequential([
    Input(shape=((x_train[0].shape[0],1)), name='inputs_nn'),
    Flatten(),    
    # Custom initial weights for deterministic behavior
    Dense(NEURONS, activation='relu', name="dense_1", kernel_initializer=initializers.GlorotUniform(seed=KERAS_SEED), bias_initializer='zeros'),
    Dense(5, activation='softmax', name='main_output', kernel_initializer=initializers.GlorotUniform(seed=KERAS_SEED), bias_initializer='zeros') 
])

model.compile(optimizer=keras.optimizers.Adam(learning_rate=LEARNING_RATE), loss='categorical_crossentropy',metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_4 (Flatten)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 20)             │           660 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ main_output (Dense)             │ (None, 5)              │           105 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 765 (2.99 KB)
#  Trainable params: 765 (2.99 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Training parameters
EPOCH_NUM = 150
BATCH_SIZE = 64

# Train model
if (CUSTOM_WEIGHTS):
    history=model.fit(x_train, y_train, epochs=EPOCH_NUM, batch_size=BATCH_SIZE, validation_data=(x_valid,y_valid), class_weight=custom_weights)
else:
    history=model.fit(x_train, y_train, epochs=EPOCH_NUM, batch_size=BATCH_SIZE, validation_data=(x_valid,y_valid))
# Out:
# Epoch 1/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.6921 - loss: 6.3012 - val_accuracy: 0.5714 - val_loss: 1.3682
# Epoch 2/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.5548 - loss: 5.5781 - val_accuracy: 0.4809 - val_loss: 1.3757
# Epoch 3/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.4743 - loss: 5.1513 - val_accuracy: 0.4231 - val_loss: 1.3447
# Epoch 4/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.4318 - loss: 4.8264 - val_accuracy: 0.4223 - val_loss: 1.3014
# Epoch 5/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.4358 - loss: 4.5638 - val_accuracy: 0.4368 - val_loss: 1.2584
# Epoch 6/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.4530 - loss: 4.3445 - val_accuracy: 0.4602 - val_loss: 1.2177
# Epoch 7/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.4773 - loss: 4.1578 - val_accuracy: 0.4859 - val_loss: 1.1800
# Epoch 8/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.5054 - loss: 3.9952 - val_accuracy: 0.5179 - val_loss: 1.1442
# Epoch 9/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.5323 - loss: 3.8513 - val_accuracy: 0.5454 - val_loss: 1.1109
# Epoch 10/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.5604 - loss: 3.7219 - val_accuracy: 0.5701 - val_loss: 1.0798
# Epoch 11/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.5846 - loss: 3.6046 - val_accuracy: 0.5930 - val_loss: 1.0512
# Epoch 12/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6062 - loss: 3.4979 - val_accuracy: 0.6122 - val_loss: 1.0250
# Epoch 13/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6241 - loss: 3.4003 - val_accuracy: 0.6307 - val_loss: 0.9996
# Epoch 14/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6416 - loss: 3.3102 - val_accuracy: 0.6451 - val_loss: 0.9764
# Epoch 15/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.6561 - loss: 3.2264 - val_accuracy: 0.6572 - val_loss: 0.9546
# Epoch 16/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6681 - loss: 3.1482 - val_accuracy: 0.6670 - val_loss: 0.9347
# Epoch 17/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6782 - loss: 3.0756 - val_accuracy: 0.6765 - val_loss: 0.9157
# Epoch 18/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.6872 - loss: 3.0081 - val_accuracy: 0.6844 - val_loss: 0.8979
# Epoch 19/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.6956 - loss: 2.9452 - val_accuracy: 0.6915 - val_loss: 0.8814
# Epoch 20/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7031 - loss: 2.8866 - val_accuracy: 0.6990 - val_loss: 0.8665
# Epoch 21/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7091 - loss: 2.8319 - val_accuracy: 0.7051 - val_loss: 0.8526
# Epoch 22/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7143 - loss: 2.7809 - val_accuracy: 0.7103 - val_loss: 0.8397
# Epoch 23/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7194 - loss: 2.7333 - val_accuracy: 0.7150 - val_loss: 0.8278
# Epoch 24/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7238 - loss: 2.6890 - val_accuracy: 0.7183 - val_loss: 0.8168
# Epoch 25/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7280 - loss: 2.6476 - val_accuracy: 0.7216 - val_loss: 0.8071
# Epoch 26/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7310 - loss: 2.6090 - val_accuracy: 0.7251 - val_loss: 0.7977
# Epoch 27/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7341 - loss: 2.5731 - val_accuracy: 0.7289 - val_loss: 0.7889
# Epoch 28/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7366 - loss: 2.5395 - val_accuracy: 0.7316 - val_loss: 0.7808
# Epoch 29/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7396 - loss: 2.5083 - val_accuracy: 0.7344 - val_loss: 0.7738
# Epoch 30/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7417 - loss: 2.4790 - val_accuracy: 0.7368 - val_loss: 0.7670
# Epoch 31/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7435 - loss: 2.4513 - val_accuracy: 0.7397 - val_loss: 0.7600
# Epoch 32/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7453 - loss: 2.4251 - val_accuracy: 0.7421 - val_loss: 0.7538
# Epoch 33/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7469 - loss: 2.4004 - val_accuracy: 0.7443 - val_loss: 0.7478
# Epoch 34/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7492 - loss: 2.3770 - val_accuracy: 0.7456 - val_loss: 0.7425
# Epoch 35/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7504 - loss: 2.3547 - val_accuracy: 0.7469 - val_loss: 0.7370
# Epoch 36/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7521 - loss: 2.3334 - val_accuracy: 0.7490 - val_loss: 0.7319
# Epoch 37/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7535 - loss: 2.3132 - val_accuracy: 0.7506 - val_loss: 0.7270
# Epoch 38/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7550 - loss: 2.2938 - val_accuracy: 0.7519 - val_loss: 0.7225
# Epoch 39/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7568 - loss: 2.2754 - val_accuracy: 0.7529 - val_loss: 0.7183
# Epoch 40/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7580 - loss: 2.2577 - val_accuracy: 0.7539 - val_loss: 0.7142
# Epoch 41/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7593 - loss: 2.2408 - val_accuracy: 0.7550 - val_loss: 0.7099
# Epoch 42/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7609 - loss: 2.2248 - val_accuracy: 0.7559 - val_loss: 0.7060
# Epoch 43/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7620 - loss: 2.2094 - val_accuracy: 0.7570 - val_loss: 0.7024
# Epoch 44/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7630 - loss: 2.1944 - val_accuracy: 0.7583 - val_loss: 0.6988
# Epoch 45/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7641 - loss: 2.1801 - val_accuracy: 0.7594 - val_loss: 0.6951
# Epoch 46/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7660 - loss: 2.1663 - val_accuracy: 0.7604 - val_loss: 0.6918
# Epoch 47/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7666 - loss: 2.1530 - val_accuracy: 0.7616 - val_loss: 0.6886
# Epoch 48/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7676 - loss: 2.1401 - val_accuracy: 0.7630 - val_loss: 0.6854
# Epoch 49/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7684 - loss: 2.1277 - val_accuracy: 0.7642 - val_loss: 0.6825
# Epoch 50/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7694 - loss: 2.1158 - val_accuracy: 0.7655 - val_loss: 0.6795
# Epoch 51/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7707 - loss: 2.1042 - val_accuracy: 0.7668 - val_loss: 0.6765
# Epoch 52/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7723 - loss: 2.0930 - val_accuracy: 0.7679 - val_loss: 0.6739
# Epoch 53/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7736 - loss: 2.0821 - val_accuracy: 0.7692 - val_loss: 0.6713
# Epoch 54/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7745 - loss: 2.0715 - val_accuracy: 0.7702 - val_loss: 0.6687
# Epoch 55/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7757 - loss: 2.0611 - val_accuracy: 0.7707 - val_loss: 0.6658
# Epoch 56/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7765 - loss: 2.0510 - val_accuracy: 0.7716 - val_loss: 0.6634
# Epoch 57/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7775 - loss: 2.0412 - val_accuracy: 0.7729 - val_loss: 0.6609
# Epoch 58/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7788 - loss: 2.0317 - val_accuracy: 0.7738 - val_loss: 0.6586
# Epoch 59/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7797 - loss: 2.0224 - val_accuracy: 0.7745 - val_loss: 0.6564
# Epoch 60/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7805 - loss: 2.0135 - val_accuracy: 0.7752 - val_loss: 0.6545
# Epoch 61/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7812 - loss: 2.0047 - val_accuracy: 0.7760 - val_loss: 0.6525
# Epoch 62/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7821 - loss: 1.9961 - val_accuracy: 0.7765 - val_loss: 0.6505
# Epoch 63/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7831 - loss: 1.9878 - val_accuracy: 0.7777 - val_loss: 0.6487
# Epoch 64/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7837 - loss: 1.9796 - val_accuracy: 0.7781 - val_loss: 0.6468
# Epoch 65/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7845 - loss: 1.9715 - val_accuracy: 0.7791 - val_loss: 0.6449
# Epoch 66/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7853 - loss: 1.9637 - val_accuracy: 0.7800 - val_loss: 0.6430
# Epoch 67/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7862 - loss: 1.9560 - val_accuracy: 0.7809 - val_loss: 0.6411
# Epoch 68/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7875 - loss: 1.9484 - val_accuracy: 0.7818 - val_loss: 0.6391
# Epoch 69/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7881 - loss: 1.9410 - val_accuracy: 0.7825 - val_loss: 0.6372
# Epoch 70/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7888 - loss: 1.9338 - val_accuracy: 0.7836 - val_loss: 0.6353
# Epoch 71/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7897 - loss: 1.9265 - val_accuracy: 0.7838 - val_loss: 0.6337
# Epoch 72/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7903 - loss: 1.9195 - val_accuracy: 0.7840 - val_loss: 0.6321
# Epoch 73/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7910 - loss: 1.9124 - val_accuracy: 0.7851 - val_loss: 0.6303
# Epoch 74/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7917 - loss: 1.9055 - val_accuracy: 0.7863 - val_loss: 0.6286
# Epoch 75/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7925 - loss: 1.8988 - val_accuracy: 0.7875 - val_loss: 0.6270
# Epoch 76/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7929 - loss: 1.8921 - val_accuracy: 0.7887 - val_loss: 0.6254
# Epoch 77/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7940 - loss: 1.8856 - val_accuracy: 0.7891 - val_loss: 0.6237
# Epoch 78/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7950 - loss: 1.8792 - val_accuracy: 0.7900 - val_loss: 0.6222
# Epoch 79/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7958 - loss: 1.8731 - val_accuracy: 0.7907 - val_loss: 0.6205
# Epoch 80/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7968 - loss: 1.8670 - val_accuracy: 0.7915 - val_loss: 0.6190
# Epoch 81/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7975 - loss: 1.8611 - val_accuracy: 0.7918 - val_loss: 0.6175
# Epoch 82/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7981 - loss: 1.8555 - val_accuracy: 0.7924 - val_loss: 0.6161
# Epoch 83/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7988 - loss: 1.8498 - val_accuracy: 0.7933 - val_loss: 0.6146
# Epoch 84/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7993 - loss: 1.8442 - val_accuracy: 0.7939 - val_loss: 0.6132
# Epoch 85/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8004 - loss: 1.8388 - val_accuracy: 0.7946 - val_loss: 0.6120
# Epoch 86/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8009 - loss: 1.8335 - val_accuracy: 0.7954 - val_loss: 0.6108
# Epoch 87/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8015 - loss: 1.8283 - val_accuracy: 0.7963 - val_loss: 0.6094
# Epoch 88/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8022 - loss: 1.8231 - val_accuracy: 0.7969 - val_loss: 0.6081
# Epoch 89/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8029 - loss: 1.8181 - val_accuracy: 0.7973 - val_loss: 0.6069
# Epoch 90/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8036 - loss: 1.8131 - val_accuracy: 0.7980 - val_loss: 0.6057
# Epoch 91/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8038 - loss: 1.8083 - val_accuracy: 0.7981 - val_loss: 0.6045
# Epoch 92/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8044 - loss: 1.8037 - val_accuracy: 0.7990 - val_loss: 0.6033
# Epoch 93/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8050 - loss: 1.7990 - val_accuracy: 0.7997 - val_loss: 0.6021
# Epoch 94/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8056 - loss: 1.7945 - val_accuracy: 0.8004 - val_loss: 0.6010
# Epoch 95/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8062 - loss: 1.7900 - val_accuracy: 0.8007 - val_loss: 0.5998
# Epoch 96/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8068 - loss: 1.7855 - val_accuracy: 0.8011 - val_loss: 0.5988
# Epoch 97/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8073 - loss: 1.7813 - val_accuracy: 0.8018 - val_loss: 0.5979
# Epoch 98/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8078 - loss: 1.7769 - val_accuracy: 0.8018 - val_loss: 0.5968
# Epoch 99/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8084 - loss: 1.7727 - val_accuracy: 0.8019 - val_loss: 0.5957
# Epoch 100/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8090 - loss: 1.7686 - val_accuracy: 0.8023 - val_loss: 0.5947
# Epoch 101/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8094 - loss: 1.7645 - val_accuracy: 0.8028 - val_loss: 0.5938
# Epoch 102/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8100 - loss: 1.7606 - val_accuracy: 0.8029 - val_loss: 0.5931
# Epoch 103/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8104 - loss: 1.7567 - val_accuracy: 0.8034 - val_loss: 0.5922
# Epoch 104/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8108 - loss: 1.7528 - val_accuracy: 0.8038 - val_loss: 0.5914
# Epoch 105/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8112 - loss: 1.7489 - val_accuracy: 0.8039 - val_loss: 0.5905
# Epoch 106/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8114 - loss: 1.7452 - val_accuracy: 0.8039 - val_loss: 0.5897
# Epoch 107/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8119 - loss: 1.7414 - val_accuracy: 0.8045 - val_loss: 0.5888
# Epoch 108/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8122 - loss: 1.7378 - val_accuracy: 0.8047 - val_loss: 0.5881
# Epoch 109/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8124 - loss: 1.7343 - val_accuracy: 0.8051 - val_loss: 0.5873
# Epoch 110/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8128 - loss: 1.7307 - val_accuracy: 0.8051 - val_loss: 0.5865
# Epoch 111/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8133 - loss: 1.7272 - val_accuracy: 0.8057 - val_loss: 0.5857
# Epoch 112/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8138 - loss: 1.7238 - val_accuracy: 0.8056 - val_loss: 0.5850
# Epoch 113/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8143 - loss: 1.7203 - val_accuracy: 0.8061 - val_loss: 0.5842
# Epoch 114/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8146 - loss: 1.7170 - val_accuracy: 0.8066 - val_loss: 0.5835
# Epoch 115/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8151 - loss: 1.7137 - val_accuracy: 0.8070 - val_loss: 0.5826
# Epoch 116/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8153 - loss: 1.7105 - val_accuracy: 0.8076 - val_loss: 0.5819
# Epoch 117/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8158 - loss: 1.7072 - val_accuracy: 0.8079 - val_loss: 0.5811
# Epoch 118/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8161 - loss: 1.7040 - val_accuracy: 0.8083 - val_loss: 0.5805
# Epoch 119/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8162 - loss: 1.7009 - val_accuracy: 0.8086 - val_loss: 0.5797
# Epoch 120/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8167 - loss: 1.6979 - val_accuracy: 0.8092 - val_loss: 0.5791
# Epoch 121/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8171 - loss: 1.6948 - val_accuracy: 0.8093 - val_loss: 0.5784
# Epoch 122/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8174 - loss: 1.6917 - val_accuracy: 0.8100 - val_loss: 0.5777
# Epoch 123/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8176 - loss: 1.6888 - val_accuracy: 0.8103 - val_loss: 0.5769
# Epoch 124/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8179 - loss: 1.6859 - val_accuracy: 0.8109 - val_loss: 0.5760
# Epoch 125/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8181 - loss: 1.6829 - val_accuracy: 0.8117 - val_loss: 0.5754
# Epoch 126/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8184 - loss: 1.6801 - val_accuracy: 0.8121 - val_loss: 0.5747
# Epoch 127/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8188 - loss: 1.6773 - val_accuracy: 0.8122 - val_loss: 0.5742
# Epoch 128/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8193 - loss: 1.6745 - val_accuracy: 0.8124 - val_loss: 0.5737
# Epoch 129/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8193 - loss: 1.6717 - val_accuracy: 0.8127 - val_loss: 0.5730
# Epoch 130/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8196 - loss: 1.6690 - val_accuracy: 0.8130 - val_loss: 0.5724
# Epoch 131/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8198 - loss: 1.6663 - val_accuracy: 0.8130 - val_loss: 0.5718
# Epoch 132/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8200 - loss: 1.6637 - val_accuracy: 0.8134 - val_loss: 0.5712
# Epoch 133/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8203 - loss: 1.6610 - val_accuracy: 0.8135 - val_loss: 0.5706
# Epoch 134/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8207 - loss: 1.6584 - val_accuracy: 0.8138 - val_loss: 0.5699
# Epoch 135/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8210 - loss: 1.6557 - val_accuracy: 0.8142 - val_loss: 0.5691
# Epoch 136/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8215 - loss: 1.6530 - val_accuracy: 0.8145 - val_loss: 0.5685
# Epoch 137/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8217 - loss: 1.6504 - val_accuracy: 0.8149 - val_loss: 0.5679
# Epoch 138/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8219 - loss: 1.6479 - val_accuracy: 0.8154 - val_loss: 0.5674
# Epoch 139/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8220 - loss: 1.6453 - val_accuracy: 0.8156 - val_loss: 0.5666
# Epoch 140/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8223 - loss: 1.6428 - val_accuracy: 0.8157 - val_loss: 0.5660
# Epoch 141/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8226 - loss: 1.6402 - val_accuracy: 0.8159 - val_loss: 0.5654
# Epoch 142/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8229 - loss: 1.6378 - val_accuracy: 0.8161 - val_loss: 0.5649
# Epoch 143/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8231 - loss: 1.6353 - val_accuracy: 0.8162 - val_loss: 0.5643
# Epoch 144/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8236 - loss: 1.6328 - val_accuracy: 0.8163 - val_loss: 0.5638
# Epoch 145/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8238 - loss: 1.6304 - val_accuracy: 0.8165 - val_loss: 0.5633
# Epoch 146/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8242 - loss: 1.6279 - val_accuracy: 0.8164 - val_loss: 0.5627
# Epoch 147/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8244 - loss: 1.6255 - val_accuracy: 0.8166 - val_loss: 0.5622
# Epoch 148/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8245 - loss: 1.6231 - val_accuracy: 0.8168 - val_loss: 0.5617
# Epoch 149/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8248 - loss: 1.6208 - val_accuracy: 0.8170 - val_loss: 0.5612
# Epoch 150/150
# 1094/1094 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8252 - loss: 1.6185 - val_accuracy: 0.8171 - val_loss: 0.5607

# %%
# Training Loss plot
loss_values = history.history['loss']
epochs = range(1, len(loss_values)+1)

plt.plot(epochs, loss_values, label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
#plt.ylim(0, 10)
plt.legend()

plt.show()

# %%
# Prediction confusion matrix
y_prediction = model.predict(x_test)
y_prediction = np.argmax(y_prediction, axis = 1)
y_test_pred = np.argmax(y_test, axis=1)


# Create confusion matrix and normalize it over predicted (columns)
#result = confusion_matrix(y_test_pred, y_prediction , normalize='pred')
result = confusion_matrix(y_test_pred, y_prediction , normalize='true')
#result = confusion_matrix(y_test_pred, y_prediction , normalize='all')
#result = confusion_matrix(y_test_pred, y_prediction)
classes = [0,1,2,3,4]
result_norm = np.around(result, 3)
#result_norm = result
mat_result = pd.DataFrame(result_norm,
                     index = classes, 
                     columns = classes)

total_pred = np.trace(result) / 5

print('Confusion matrix')
print(mat_result)
print()
print('Average accuracy')
print(total_pred)
# Out:
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 1s 934us/step
# Confusion matrix
#        0      1      2      3      4
# 0  0.799  0.099  0.030  0.045  0.027
# 1  0.118  0.827  0.039  0.006  0.010
# 2  0.033  0.048  0.804  0.083  0.032
# 3  0.051  0.008  0.042  0.890  0.008
# 4  0.026  0.002  0.015  0.004  0.953
#
# Average accuracy
# 0.8545900649598277

# %%
# Print detailed results
target_names = ['class 0', 'class 1', 'class 2', 'class 3', 'class 4']
print(classification_report(y_test_pred, y_prediction, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.99      0.80      0.88     14483
#      class 1       0.21      0.83      0.34       485
#      class 2       0.65      0.80      0.72      1093
#      class 3       0.12      0.89      0.21       118
#      class 4       0.74      0.95      0.84      1322
#
#     accuracy                           0.81     17501
#    macro avg       0.54      0.85      0.60     17501
# weighted avg       0.92      0.81      0.85     17501

# %%
model_num = 0
#while os.path.exists(MODEL_PATH_BASE + MODEL_NAME_BASE + "%s.keras" % f"{model_num:02}"):
#    model_num += 1
log_dir = LOG_DIR
#model_name = MODEL_NAME_BASE+ str(f"{model_num:02}")
model_name = MODEL_NAME_BASE+ str(f"{NEURONS:02}")
model_path = MODEL_PATH_BASE + model_name + '.keras'
model.name = model_name
#model.save(model_path)

# %%
model_name = "mlp_bt"+str(f"{HEARTBEAT_LENGTH:03}")+"_pk"+str(f"{DELTA_PEAK:03}")+"_t"+str(f"{DELTA_TIME:03}")+"_n"+str(f"{NEURONS:02}")+"_eq8bit"

# %%
figure = plt.figure(figsize=(4, 4))
sns.heatmap(mat_result, annot=True,cmap=plt.cm.Blues)
plt.title(model_name)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.tight_layout()
#plt.savefig(log_dir + '/' + model_name + '.png', pad_inches=0.1)
plt.show()
